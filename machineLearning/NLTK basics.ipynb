# %%
import nltk
nltk.download('all')
#nltk.download('punkt')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
f = """What is Firstcry? 
Firstcry is Asia's largest online store for baby and kids products. We cater to the needs of our buyers (mothers buying for their kids) from before the kid is born upto his/her early teens. 

What is the benefit of buying from Firstcry?
Our company philosophy is pretty simple: We want to offer the best possible deal for our customers for the products that we all want to buy for our children. Our endeavour is to ensure that you get the widest possible choice of top rated brands and products at the best possible price anywhere in India combined with best possible service and timely delivery of products at your doorstep. 

Where are the offices of FirstCry located?
Currently our office is located in Pune while the orders are shipped from our warehouses located across India. 

What products does Firstcry sell?
We sell products of all the leading brands for babies and kids across sections right from diapers, baby food, infant accessories, gears (strollers, high chairs), nursery furniture, clothes & footwear to toys and school products. We also stock items from some of the leading importers and domestic manufacturers of the country. The items undergo a thorough check by our QA team before they are stocked. 

What's the minimum order value required to place an order?
To place an order, a minimum order value of Rs. 249 or more is required (Excluding COD charges, Shipping charges, Taxes or value reduced after application of coupons or any other offer). 

How do I know my order has been confirmed?
After checking out during the payment process, you will get a confirmation that your payment has been processed successfully. You will also get a mail in your registered email id, along with an SMS to your registered mobile number confirming the order. 

How do I check my order status?
We will ship your package within 24 hours of receiving the order. We will also mail you the name of the courier company and the tracking number of your consignment to your registered email address. You will receive an SMS about the same. In case you do not receive an email from us within 24 hours of placing an order please check your spam folder. Tracking may not appear online for up to another 24 hours in some cases, so please wait until your package is scanned by the courier company. Alternatively, you can check the same in My Account page, where Track Shipment option gives you the current status of your order being shipped. 

Is it safe to use my Credit Card Online at Firstcry.com?
We accept VISA, MASTER and AMERICAN EXPRESS Credit Cards issued in India and we accept Debit cards of all banks issued in India. International credit/debit card transactions are also accepted through Paypal, so now you can place orders with Firstcry from outside India and we will ship it to your dear ones in India. All your transactions online are protected & secured by SSL (secure socket layer) technology from GoDaddy.com. It encrypts your credit card and relevant information during the entire transaction process. This encryption makes your shopping experience safe and secure. 

What if an item is out of stock?
We make every effort to keep all products in stock. However, there may be times when unexpected demands exceed our supply. We will notify you at the time of check out if the item selected is not in stock. In the rare circumstance where the order has been accepted and due to some reasons we are not able to ship, we will notify you within 24 hours and the money will be returned to you in the same mode by which the payment was made within 10 working days. Some items (which are restocked regularly) and is temporarily out of stock may appear on display with an out of stock tag. You can use the Notify Me option and we will inform you once the product is replenished and available for sale. 

Are there any other hidden charges like Octroi or Entry tax?
You will get the final price during check out. Our prices are all inclusive and you need not pay anything extra.

How are the products packaged?
Each of the individual products are securely packaged in bubble wrap and put into a box. The box is sealed well ensuring a safe delivery to your doorstep. 

Do you'll deliver products outside India?
We do not ship products outside India but the site is accessible to all and we do take orders from around the world provided the shipping address is in India. 

Is it mandatory to register before placing an order?
You can place your order by just providing us with your email address. However, it is recommended that you register with us in order to receive timely offers and also to maintain your Wishlist and account & address details. 

How long will it take to receive my orders?
For all areas serviced by reputed couriers, the delivery time would be within 3 to 4 business days after dispatch (business days exclude Sundays and other holidays). However items weighing over 2 kilos may take a couple of days longer to reach. For other areas the products will be shipped through Indian Postal Service and may take 1-2 weeks depending on the location. 

Can I ship different items in my order to different shipping addresses?
We can only process one shipping address per order. So, if you would like to order several items and ship to different people, please treat these as separate orders. 

Who pays for the shipping charges? 
We provide Free Shipping on all Orders above or equal to Rs. 499/- (Excluding COD charges, Shipping charges, Taxes or value reduced after application of coupons or any other offer). For Orders below Rs. 499 (with exclusions as above), shipping charges of Rs. 50 will apply.

What is GST? 
GST means Goods and Service Tax. It is a single indirect tax on the sale of goods and services throughout India. GST is applicable w.e.f. 1st July, 2017. 

How GST amount is calculated over and above the discounted price? 
GST is calculated on the basis of rates mentioned under GST laws for each category of product, customer location and the applicable discount on the product at the time of purchase.GST over and above the discounted price is applicable on products with discount of 19% and above. Please refer to Terms of Use for full details. The GST collected on the discounted price is duly deposited with the respective GST Authorities having jurisdiction or adjusted as per the applicable GST Act and Rules 

Do I have to pay GST on purchase of Gift Certificate & Guaranteed Savings Offer? 
No. GST is not charged from customers on buying Gift Certificates and Guaranteed Savings Offer. 

Will my GST amount be refunded on Order Cancellation and Returns? 
Yes. GST amount collected will be returned to customer's source method at the time of Cancellation and Returns. 

What to do if GST amount on purchased products comes out to be more than the limit defined by the Govt.? 
We are ready to share all details of GST for your kind perusal and would happily return your money back in case we found any excessive amount being charged due to miscalculation. 

What happens if I am not available at the time of delivery?
Our delivery partners will attempt to deliver the package thrice before it is returned back to our warehouse. Please provide your mobile number in the delivery address as it will help in making a faster delivery. 

What is your Return Policy?
We have a 30 days return policy for Clothes & Footwear and a 7 days return policy for all other items except for Personal Products such as Diapers, Wipes and Creams. 

What options do I have while making payment? 
We accept payments by debit or credit card and also through Net Banking.Credit Cards & Debit Cards - We accept VISA, MASTER and AMERICAN EXPRESS Credit Cards issued in India and we accept Debit cards of all banks issued in India. International credit/debit card transactions are also accepted through Pay pal.Net Banking - We Accept Axis Bank, Bank of Baroda (Retail & Corporate Banking), Bank Of India, Bank of Maharashtra, Canara Bank, Corporation Bank, Citibank, Deutsche Bank, Federal Bank Fed Net Banking, HDFC Bank, ICICI Bank, IDBI i Net Banking, IndusInd Bank, ING Vysya Bank Ltd., Jammu & Kashmir Bank, Karnataka Bank, Karur Vysya Bank Limited, Kotak Mahindra Bank, Lakshmi Vilas Bank, Oriental Bank Of Commerce, Punjab National Bank, The Bank Of Rajasthan, Royal Bank of Scotland, South Indian Bank, State Bank Of India, State Bank of Indore, State Bank of Hyderabad, State Bank of Travancore, Syndicate Bank, Tamilnad Mercantile Bank Ltd., Union Bank Of India, Vijaya Bank, Yes Bank You can also pay through Cash On Delivery (C-O-D) - You can also pay through Cash On Delivery (COD). In this case you pay in Cash to the courier person while accepting the goods. COD payments would be accepted for orders with total invoice value greater than equal to Rs. 499/- and up to Rs. 15,000/-."""

f.replace('<','')
f.replace('>','')
# Out:
# "What is Firstcry? \nFirstcry is Asia's largest online store for baby and kids products. We cater to the needs of our buyers (mothers buying for their kids) from before the kid is born upto his/her early teens. \n\nWhat is the benefit of buying from Firstcry?\nOur company philosophy is pretty simple: We want to offer the best possible deal for our customers for the products that we all want to buy for our children. Our endeavour is to ensure that you get the widest possible choice of top rated brands and products at the best possible price anywhere in India combined with best possible service and timely delivery of products at your doorstep. \n\nWhere are the offices of FirstCry located?\nCurrently our office is located in Pune while the orders are shipped from our warehouses located across India. \n\nWhat products does Firstcry sell?\nWe sell products of all the leading brands for babies and kids across sections right from diapers, baby food, infant accessories, gears (strollers, high chairs), nursery furniture, clothes & footwear to toys and school products. We also stock items from some of the leading importers and domestic manufacturers of the country. The items undergo a thorough check by our QA team before they are stocked. \n\nWhat's the minimum order value required to place an order?\nTo place an order, a minimum order value of Rs. 249 or more is required (Excluding COD charges, Shipping charges, Taxes or value reduced after application of coupons or any other offer). \n\nHow do I know my order has been confirmed?\nAfter checking out during the payment process, you will get a confirmation that your payment has been processed successfully. You will also get a mail in your registered email id, along with an SMS to your registered mobile number confirming the order. \n\nHow do I check my order status?\nWe will ship your package within 24 hours of receiving the order. We will also mail you the name of the courier company and the tracking number of your consignment to your registered email address. You will receive an SMS about the same. In case you do not receive an email from us within 24 hours of placing an order please check your spam folder. Tracking may not appear online for up to another 24 hours in some cases, so please wait until your package is scanned by the courier company. Alternatively, you can check the same in My Account page, where Track Shipment option gives you the current status of your order being shipped. \n\nIs it safe to use my Credit Card Online at Firstcry.com?\nWe accept VISA, MASTER and AMERICAN EXPRESS Credit Cards issued in India and we accept Debit cards of all banks issued in India. International credit/debit card transactions are also accepted through Paypal, so now you can place orders with Firstcry from outside India and we will ship it to your dear ones in India. All your transactions online are protected & secured by SSL (secure socket layer) technology from GoDaddy.com. It encrypts your credit card and relevant information during the entire transaction process. This encryption makes your shopping experience safe and secure. \n\nWhat if an item is out of stock?\nWe make every effort to keep all products in stock. However, there may be times when unexpected demands exceed our supply. We will notify you at the time of check out if the item selected is not in stock. In the rare circumstance where the order has been accepted and due to some reasons we are not able to ship, we will notify you within 24 hours and the money will be returned to you in the same mode by which the payment was made within 10 working days. Some items (which are restocked regularly) and is temporarily out of stock may appear on display with an out of stock tag. You can use the Notify Me option and we will inform you once the product is replenished and available for sale. \n\nAre there any other hidden charges like Octroi or Entry tax?\nYou will get the final price during check out. Our prices are all inclusive and you ...

# %% [markdown]
# Sentence Tokenisation

# %%
text= nltk.sent_tokenize(f)

# %%
import csv
with open('firstcry_faqs.csv', mode='w') as firstcry_faqs_file:
    fieldnames = ['SENTENCE', 'CLASS']
    firstcry_faqs_writer = csv.writer(firstcry_faqs_file, delimiter=',')
    firstcry_faqs_writer.writerow(fieldnames)
    for line in text:
        if '?' in line:
            #print(line)
            firstcry_faqs_writer.writerow([line, 'Q'])
        elif line=='':
            pass
        else:
            firstcry_faqs_writer.writerow([line, 'S'])

# %%
import pandas as pd
sentences = pd.read_csv(filepath_or_buffer = 'firstcry_faqs.csv') 
sentences.head(10)
# Out:
#                                             SENTENCE CLASS
# 0                                  What is Firstcry?     Q
# 1  Firstcry is Asia's largest online store for ba...     S
# 2  We cater to the needs of our buyers (mothers b...     S
# 3       What is the benefit of buying from Firstcry?     Q
# 4  Our company philosophy is pretty simple: We wa...     S
# 5  Our endeavour is to ensure that you get the wi...     S
# 6         Where are the offices of FirstCry located?     Q
# 7  Currently our office is located in Pune while ...     S
# 8                  What products does Firstcry sell?     Q
# 9  We sell products of all the leading brands for...     S

# %%
features = {}
token_words=[]
for t in text:
    for word in nltk.word_tokenize(t):
        #print(word)
        token_words.append(word)

# %%
print(features)
# Out:
# {}

# %% [markdown]
# Stemming

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()
 
sentence = "gaming, the gamers play games"


for sentence in text:
    words = word_tokenize(sentence)
    for word in words:
        print(word + ":" + ps.stem(word))
# Out:
# What:what
# is:is
# Firstcry:firstcri
# ?:?
# Firstcry:firstcri
# is:is
# Asia:asia
# 's:'s
# largest:largest
# online:onlin
# store:store
# for:for
# baby:babi
# and:and
# kids:kid
# products:product
# .:.
# We:We
# cater:cater
# to:to
# the:the
# needs:need
# of:of
# our:our
# buyers:buyer
# (:(
# mothers:mother
# buying:buy
# for:for
# their:their
# kids:kid
# ):)
# from:from
# before:befor
# the:the
# kid:kid
# is:is
# born:born
# upto:upto
# his/her:his/her
# early:earli
# teens:teen
# .:.
# What:what
# is:is
# the:the
# benefit:benefit
# of:of
# buying:buy
# from:from
# Firstcry:firstcri
# ?:?
# Our:our
# company:compani
# philosophy:philosophi
# is:is
# pretty:pretti
# simple:simpl
# :::
# We:We
# want:want
# to:to
# offer:offer
# the:the
# best:best
# possible:possibl
# deal:deal
# for:for
# our:our
# customers:custom
# for:for
# the:the
# products:product
# that:that
# we:we
# all:all
# want:want
# to:to
# buy:buy
# for:for
# our:our
# children:children
# .:.
# Our:our
# endeavour:endeavour
# is:is
# to:to
# ensure:ensur
# that:that
# you:you
# get:get
# the:the
# widest:widest
# possible:possibl
# choice:choic
# of:of
# top:top
# rated:rate
# brands:brand
# and:and
# products:product
# at:at
# the:the
# best:best
# possible:possibl
# price:price
# anywhere:anywher
# in:in
# India:india
# combined:combin
# with:with
# best:best
# possible:possibl
# service:servic
# and:and
# timely:time
# delivery:deliveri
# of:of
# products:product
# at:at
# your:your
# doorstep:doorstep
# .:.
# Where:where
# are:are
# the:the
# offices:offic
# of:of
# FirstCry:firstcri
# located:locat
# ?:?
# Currently:current
# our:our
# office:offic
# is:is
# located:locat
# in:in
# Pune:pune
# while:while
# the:the
# orders:order
# are:are
# shipped:ship
# from:from
# our:our
# warehouses:warehous
# located:locat
# across:across
# India:india
# .:.
# What:what
# products:product
# does:doe
# Firstcry:firstcri
# sell:sell
# ?:?
# We:We
# sell:sell
# products:product
# of:of
# all:all
# the:the
# leading:lead
# brands:brand
# for:for
# babies:babi
# and:and
# kids:kid
# across:across
# sections:section
# right:right
# from:from
# diapers:diaper
# ,:,
# baby:babi
# food:food
# ,:,
# infant:infant
# accessories:accessori
# ,:,
# gears:gear
# (:(
# strollers:stroller
# ,:,
# high:high
# chairs:chair
# ):)
# ,:,
# nursery:nurseri
# furniture:furnitur
# ,:,
# clothes:cloth
# &:&
# footwear:footwear
# to:to
# toys:toy
# and:and
# school:school
# products:product
# .:.
# We:We
# also:also
# stock:stock
# items:item
# from:from
# some:some
# of:of
# the:the
# leading:lead
# importers:import
# and:and
# domestic:domest
# manufacturers:manufactur
# of:of
# the:the
# country:countri
# .:.
# The:the
# items:item
# undergo:undergo
# a:a
# thorough:thorough
# check:check
# by:by
# our:our
# QA:QA
# team:team
# before:befor
# they:they
# are:are
# stocked:stock
# .:.
# What:what
# 's:'s
# the:the
# minimum:minimum
# order:order
# value:valu
# required:requir
# to:to
# place:place
# an:an
# order:order
# ?:?
# To:To
# place:place
# an:an
# order:order
# ,:,
# a:a
# minimum:minimum
# order:order
# value:valu
# of:of
# Rs:Rs
# .:.
# 249:249
# or:or
# more:more
# is:is
# required:requir
# (:(
# Excluding:exclud
# COD:cod
# charges:charg
# ,:,
# Shipping:ship
# charges:charg
# ,:,
# Taxes:tax
# or:or
# value:valu
# reduced:reduc
# after:after
# application:applic
# of:of
# coupons:coupon
# or:or
# any:ani
# other:other
# offer:offer
# ):)
# .:.
# How:how
# do:do
# I:I
# know:know
# my:my
# order:order
# has:ha
# been:been
# confirmed:confirm
# ?:?
# After:after
# checking:check
# out:out
# during:dure
# the:the
# payment:payment
# process:process
# ,:,
# you:you
# will:will
# get:get
# a:a
# confirmation:confirm
# that:that
# your:your
# payment:payment
# has:ha
# been:been
# processed:process
# successfully:success
# .:.
# You:you
# will:will
# also:also
# get:get
# a:a
# mail:mail
# in:in
# your:your
# registered:regist
# email:email
# id:id
# ,:,
# along:along
# with:with
# an:an
# SMS:sm
# to:to
# your:your
# registered:regist
# mobile:mobil
# number:number
# confirming:confirm
# the:the
# order:order
# .:.
# How:how
# do:do
# I:I
# check:check
# my:my
# order:order
# status:statu
# ?:?
# We:We
# will:will
# ship:ship
# your:your
# package:packag
# within:within
# 24:24
# hours:hour
# of:of
# receiving:receiv
# the:the
# order:order
# .:.
# We:We
# will:will
# also:also
# mail:mail
# you:you
# the:the
# name:name
# of:of
# the:the
# courier:courier
# company:compani
# and:and
# the:the
# tracking:track
# number:number
# of:of
# your:your
# consignment:consign
# to:to
# your:your
# registered:regist
# email:email
# address:address
# .:.
# You:you
# will:will
# receive:receiv
# an:an
# SMS:sm
# about:about
# the:the
# same:same
# .:.
# In:In
# case:case
# you:you
# do:do
# not:not
# receive:receiv
# an:an
# email:email
# from:from
# us:us
# within:within
# 24:24
# hours:hour
# of:of
# placing:place
# an:an
# order:order
# please:pleas
# check:check
# your:your
# spam:spam
# folder:folder
# .:.
# Tracking:track
# may:may
# not:not
# appear:appear
# online:onlin
# for:for
# up:up
# to:to
# another:anoth
# 24:24
# hours:hour
# in:in
# some:some
# cases:case
# ,:,
# so:so
# please:pleas
# wait:wait
# until:until
# your:your
# package:packag
# is:is
# scanned:scan
# by:by
# the:the
# courier:courier
# company:compani
# .:.
# Alternatively:altern
# ,:,
# you:you
# can:can
# check:check
# the:the
# same:same
# in:in
# My:My
# Account:account
# page:page
# ,:,
# where:where
# Track:track
# Shipment:shipment
# option:option
# gives:give
# you:you
# the:the
# current:current
# status:statu
# of:of
# your:your
# order:order
# being:be
# shipped:ship
# .:.
# Is:Is
# it:it
# safe:safe
# to:to
# use:use
# my:my
# Credit:credit
# Card:card
# Online:onlin
# at:at
# Firstcry.com:firstcry.com
# ?:?
# We:We
# accept:accept
# VISA:visa
# ,:,
# MASTER:master
# and:and
# AMERICAN:american
# EXPRESS:express
# Credit:credit
# Cards:card
# issued:issu
# in:in
# India:india
# and:and
# we:we
# accept:accept
# Debit:debit
# cards:card
# of:of
# all:all
# banks:bank
# issued:issu
# in:in
# India:india
# .:.
# International:intern
# credit/debit:credit/debit
# card:card
# transactions:transact
# are:are
# also:also
# accepted:accept
# through:through
# Paypal:paypal
# ,:,
# so:so
# now:now
# you:you
# can:can
# place:place
# orders:order
# with:with
# Firstcry:firstcri
# from:from
# outside:outsid
# India:india
# and:and
# we:we
# will:will
# ship:ship
# it:it
# to:to
# your:your
# dear:dear
# ones:one
# in:in
# India:india
# .:.
# All:all
# your:your
# transactions:transact
# online:onlin
# are:are
# protected:protect
# &:&
# secured:secur
# by:by
# SSL:ssl
# (:(
# secure:secur
# socket:socket
# layer:layer
# ):)
# technology:technolog
# from:from
# GoDaddy.com:godaddy.com
# .:.
# It:It
# encrypts:encrypt
# your:your
# credit:credit
# card:card
# and:and
# relevant:relev
# information:inform
# during:dure
# the:the
# entire:entir
# transaction:transact
# process:process
# .:.
# This:thi
# encryption:encrypt
# makes:make
# your:your
# shopping:shop
# experience:experi
# safe:safe
# and:and
# secure:secur
# .:.
# What:what
# if:if
# an:an
# item:item
# is:is
# out:out
# of:of
# stock:stock
# ?:?
# We:We
# make:make
# every:everi
# effort:effort
# to:to
# keep:keep
# all:all
# products:product
# in:in
# stock:stock
# .:.
# However:howev
# ,:,
# there:there
# may:may
# be:be
# times:time
# when:when
# unexpected:unexpect
# demands:demand
# exceed:exceed
# our:our
# supply:suppli
# .:.
# We:We
# will:will
# notify:notifi
# you:you
# at:at
# the:the
# time:time
# of:of
# check:check
# out:out
# if:if
# the:the
# item:item
# selected:select
# is:is
# not:not
# in:in
# stock:stock
# .:.
# In:In
# the:the
# rare:rare
# circumstance:circumst
# where:where
# the:the
# order:order
# has:ha
# been:been
# accepted:accept
# and:and
# due:due
# to:to
# some:some
# reasons:reason
# we:we
# are:are
# not:not
# able:abl
# to:to
# ship:ship
# ,:,
# we:we
# will:will
# notify:notifi
# you:you
# within:within
# 24:24
# hours:hour
# and:and
# the:the
# money:money
# will:will
# be:be
# returned:return
# to:to
# you:you
# in:in
# the:the
# same:same
# mode:mode
# by:by
# which:which
# the:the
# payment:payment
# was:wa
# made:made
# within:within
# 10:10
# working:work
# days:day
# .:.
# Some:some
# items:item
# (:(
# which:which
# are:are
# restocked:restock
# regularly:regularli
# ):)
# and:and
# is:is
# temporarily:temporarili
# out:out
# of:of
# stock:stock
# may:may
# appear:appear
# on:on
# display:display
# with:with
# an:an
# out:out
# of:of
# stock:stock
# tag:tag
# .:.
# You:you
# can:can
# use:use
# the:the
# Notify:notifi
# Me:Me
# option:option
# and:and
# we:we
# will:will
# inform:inform
# you:you
# once:onc
# the:the
# product:product
# is:is
# replenished:replenish
# and:and
# available:avail
# for:for
# sale:sale
# .:.
# Are:are
# there:there
# any:ani
# other:other
# hidden:hidden
# charges:charg
# like:like
# Octroi:octroi
# or:or
# Entry:entri
# tax:tax
# ?:?
# You:you
# will:will
# get:get
# the:the
# final:final
# price:price
# during:dure
# check:check
# out:out
# .:.
# Our:our
# prices:price
# are:are
# all:all
# inclusive:inclus
# and:and
# you:you
# need:need
# not:not
# pay:pay
# anything:anyth
# extra:extra
# .:.
# How:how
# are:are
# the:the
# products:product
# packaged:packag
# ?:?
# Each:each
# of:of
# the:the
# individual:individu
# products:product
# are:are
# securely:secur
# packaged:packag
# in:in
# bubble:bubbl
# wrap:wrap
# and:and
# put:put
# into:into
# a:a
# box:box
# .:.
# The:the
# box:box
# is:is
# sealed:seal
# well:well
# ensuring:ensur
# a:a
# safe:safe
# delivery:deliveri
# to:to
# your:your
# doorstep:doorstep
# .:.
# Do:Do
# you:you
# 'll:'ll
# deliver:deliv
# products:product
# outside:outsid
# India:india
# ?:?
# We:We
# do:do
# not:not
# ship:ship
# products:product
# outside:outsid
# India:india
# but:but
# the:the
# site:site
# is:is
# accessible:access
# to:to
# all:all
# and:and
# we:we
# do:do
# take:take
# orders:order
# from:from
# around:around
# the:the
# world:world
# provided:provid
# the:the
# shipping:ship
# address:address
# is:is
# in:in
# India:india
# .:.
# Is:Is
# it:it
# mandatory:mandatori
# to:to
# register:regist
# before:befor
# placing:place
# an:an
# order:order
# ?:?
# You:you
# can:can
# place:place
# your:your
# order:order
# by:by
# just:just
# providing:provid
# us:us
# with:with
# your:your
# email:email
# address:address
# .:.
# However:howev
# ,:,
# it:it
# is:is
# recommended:recommend
# that:that
# you:you
# register:regist
# with:with
# us:us
# in:in
# order:order
# to:to
# receive:receiv
# timely:time
# offers:offer
# and:and
# also:also
# to:to
# maintain:maintain
# your:your
# Wishlist:wishlist
# and:and
# account:account
# &:&
# address:address
# details:detail
# .:.
# How:how
# long:long
# will:will
# it:it
# take:take
# to:to
# receive:receiv
# my:my
# orders:order
# ?:?
# For:for
# all:all
# areas:area
# serviced:servic
# by:by
# reputed:reput
# couriers:courier
# ,:,
# the:the
# delivery:deliveri
# time:time
# would:would
# be:be
# within:within
# 3:3
# to:to
# 4:4
# business:busi
# days:day
# after:after
# dispatch:dispatch
# (:(
# business:busi
# days:day
# exclude:exclud
# Sundays:sunday
# and:and
# other:other
# holidays:holiday
# ):)
# .:.
# However:howev
# items:item
# weighing:weigh
# over:over
# 2:2
# kilos:kilo
# may:may
# take:take
# a:a
# couple:coupl
# of:of
# days:day
# longer:longer
# to:to
# reach:reach
# .:.
# For:for
# other:other
# areas:area
# the:the
# products:product
# will:will
# be:be
# shipped:ship
# through:through
# Indian:indian
# Postal:postal
# Service:servic
# and:and
# may:may
# take:take
# 1-2:1-2
# weeks:week
# depending:depend
# on:on
# the:the
# location:locat
# .:.
# Can:can
# I:I
# ship:ship
# different:differ
# items:item
# in:in
# my:my
# order:order
# to:to
# different:differ
# shipping:ship
# addresses:address
# ?:?
# We:We
# can:can
# only:onli
# process:process
# one:one
# shipping:ship
# address:address
# per:per
# order:order
# .:.
# So:So
# ,:,
# if:if
# you:you
# would:would
# like:like
# to:to
# order:order
# several:sever
# items:item
# and:and
# ship:ship
# to:to
# different:differ
# people:peopl
# ,:,
# please:pleas
# treat:treat
# these:these
# as:as
# separate:separ
# orders:order
# .:.
# Who:who
# pays:pay
# for:for
# the:the
# shipping:ship
# charges:charg
# ?:?
# We:We
# provide:provid
# Free:free
# Shipping:ship
# on:on
# all:all
# Orders:order
# above:abov
# or:or
# equal:equal
# to:to
# Rs:Rs
# .:.
# 499/-:499/-
# (:(
# Excluding:exclud
# COD:cod
# charges:charg
# ,:,
# Shipping:ship
# charges:charg
# ,:,
# Taxes:tax
# or:or
# value:valu
# reduced:reduc
# after:after
# application:applic
# of:of
# coupons:coupon
# or:or
# any:ani
# other:other
# offer:offer
# ):)
# .:.
# For:for
# Orders:order
# below:below
# Rs:Rs
# .:.
# 499:499
# (:(
# with:with
# exclusions:exclus
# as:as
# above:abov
# ):)
# ,:,
# shipping:ship
# charges:charg
# of:of
# Rs:Rs
# .:.
# 50:50
# will:will
# apply:appli
# .:.
# What:what
# is:is
# GST:gst
# ?:?
# GST:gst
# means:mean
# Goods:good
# and:and
# Service:servic
# Tax:tax
# .:.
# It:It
# is:is
# a:a
# single:singl
# indirect:indirect
# tax:tax
# on:on
# the:the
# sale:sale
# of:of
# goods:good
# and:and
# services:servic
# throughout:throughout
# India:india
# .:.
# GST:gst
# is:is
# applicable:applic
# w.e.f:w.e.f
# .:.
# 1st:1st
# July:juli
# ,:,
# 2017:2017
# .:.
# How:how
# GST:gst
# amount:amount
# is:is
# calculated:calcul
# over:over
# and:and
# above:abov
# the:the
# discounted:discount
# price:price
# ?:?
# GST:gst
# is:is
# calculated:calcul
# on:on
# the:the
# basis:basi
# of:of
# rates:rate
# mentioned:mention
# under:under
# GST:gst
# laws:law
# for:for
# each:each
# category:categori
# of:of
# product:product
# ,:,
# customer:custom
# location:locat
# and:and
# the:the
# applicable:applic
# discount:discount
# on:on
# the:the
# product:product
# at:at
# the:the
# time:time
# of:of
# purchase.GST:purchase.gst
# over:over
# and:and
# above:abov
# the:the
# discounted:discount
# price:price
# is:is
# applicable:applic
# on:on
# products:product
# with:with
# discount:discount
# of:of
# 19:19
# %:%
# and:and
# above:abov
# .:.
# Please:pleas
# refer:refer
# to:to
# Terms:term
# of:of
# Use:use
# for:for
# full:full
# details:detail
# .:.
# The:the
# GST:gst
# collected:collect
# on:on
# the:the
# discounted:discount
# price:price
# is:is
# duly:duli
# deposited:deposit
# with:with
# the:the
# respective:respect
# GST:gst
# Authorities:author
# having:have
# jurisdiction:jurisdict
# or:or
# adjusted:adjust
# as:as
# per:per
# the:the
# applicable:applic
# GST:gst
# Act:act
# and:and
# Rules:rule
# Do:Do
# I:I
# have:have
# to:to
# pay:pay
# GST:gst
# on:on
# purchase:purchas
# of:of
# Gift:gift
# Certificate:certif
# &:&
# Guaranteed:guarante
# Savings:save
# Offer:offer
# ?:?
# No:No
# .:.
# GST:gst
# is:is
# not:not
# charged:charg
# from:from
# customers:custom
# on:on
# buying:buy
# Gift:gift
# Certificates:certif
# and:and
# Guaranteed:guarante
# Savings:save
# Offer:offer
# .:.
# Will:will
# my:my
# GST:gst
# amount:amount
# be:be
# refunded:refund
# on:on
# Order:order
# Cancellation:cancel
# and:and
# Returns:return
# ?:?
# Yes:ye
# .:.
# GST:gst
# amount:amount
# collected:collect
# will:will
# be:be
# returned:return
# to:to
# customer:custom
# 's:'s
# source:sourc
# method:method
# at:at
# the:the
# time:time
# of:of
# Cancellation:cancel
# and:and
# Returns:return
# .:.
# What:what
# to:to
# do:do
# if:if
# GST:gst
# amount:amount
# on:on
# purchased:purchas
# products:product
# comes:come
# out:out
# to:to
# be:be
# more:more
# than:than
# the:the
# limit:limit
# defined:defin
# by:by
# the:the
# Govt:govt
# .:.
# ?:?
# We:We
# are:are
# ready:readi
# to:to
# share:share
# all:all
# details:detail
# of:of
# GST:gst
# for:for
# your:your
# kind:kind
# perusal:perus
# and:and
# would:would
# happily:happili
# return:return
# your:your
# money:money
# back:back
# in:in
# case:case
# we:we
# found:found
# any:ani
# excessive:excess
# amount:amount
# being:be
# charged:charg
# due:due
# to:to
# miscalculation:miscalcul
# .:.
# What:what
# happens:happen
# if:if
# I:I
# am:am
# not:not
# available:avail
# at:at
# the:the
# time:time
# of:of
# delivery:deliveri
# ?:?
# Our:our
# delivery:deliveri
# partners:partner
# will:will
# attempt:attempt
# to:to
# deliver:deliv
# the:the
# package:packag
# thrice:thrice
# before:befor
# it:it
# is:is
# returned:return
# back:back
# to:to
# our:our
# warehouse:warehous
# .:.
# Please:pleas
# provide:provid
# your:your
# mobile:mobil
# number:number
# in:in
# the:the
# delivery:deliveri
# address:address
# as:as
# it:it
# will:will
# help:help
# in:in
# making:make
# a:a
# faster:faster
# delivery:deliveri
# .:.
# What:what
# is:is
# your:your
# Return:return
# Policy:polici
# ?:?
# We:We
# have:have
# a:a
# 30:30
# days:day
# return:return
# policy:polici
# for:for
# Clothes:cloth
# &:&
# Footwear:footwear
# and:and
# a:a
# 7:7
# days:day
# return:return
# policy:polici
# for:for
# all:all
# other:other
# items:item
# except:except
# for:for
# Personal:person
# Products:product
# such:such
# as:as
# Diapers:diaper
# ,:,
# Wipes:wipe
# and:and
# Creams:cream
# .:.
# What:what
# options:option
# do:do
# I:I
# have:have
# while:while
# making:make
# payment:payment
# ?:?
# We:We
# accept:accept
# payments:payment
# by:by
# debit:debit
# or:or
# credit:credit
# card:card
# and:and
# also:also
# through:through
# Net:net
# Banking.Credit:banking.credit
# Cards:card
# &:&
# Debit:debit
# Cards:card
# -:-
# We:We
# accept:accept
# VISA:visa
# ,:,
# MASTER:master
# and:and
# AMERICAN:american
# EXPRESS:express
# Credit:credit
# Cards:card
# issued:issu
# in:in
# India:india
# and:and
# we:we
# accept:accept
# Debit:debit
# cards:card
# of:of
# all:all
# banks:bank
# issued:issu
# in:in
# India:india
# .:.
# International:intern
# credit/debit:credit/debit
# card:card
# transactions:transact
# are:are
# also:also
# accepted:accept
# through:through
# Pay:pay
# pal.Net:pal.net
# Banking:bank
# -:-
# We:We
# Accept:accept
# Axis:axi
# Bank:bank
# ,:,
# Bank:bank
# of:of
# Baroda:baroda
# (:(
# Retail:retail
# &:&
# Corporate:corpor
# Banking:bank
# ):)
# ,:,
# Bank:bank
# Of:Of
# India:india
# ,:,
# Bank:bank
# of:of
# Maharashtra:maharashtra
# ,:,
# Canara:canara
# Bank:bank
# ,:,
# Corporation:corpor
# Bank:bank
# ,:,
# Citibank:citibank
# ,:,
# Deutsche:deutsch
# Bank:bank
# ,:,
# Federal:feder
# Bank:bank
# Fed:fed
# Net:net
# Banking:bank
# ,:,
# HDFC:hdfc
# Bank:bank
# ,:,
# ICICI:icici
# Bank:bank
# ,:,
# IDBI:idbi
# i:i
# Net:net
# Banking:bank
# ,:,
# IndusInd:indusind
# Bank:bank
# ,:,
# ING:ing
# Vysya:vysya
# Bank:bank
# Ltd.:ltd.
# ,:,
# Jammu:jammu
# &:&
# Kashmir:kashmir
# Bank:bank
# ,:,
# Karnataka:karnataka
# Bank:bank
# ,:,
# Karur:karur
# Vysya:vysya
# Bank:bank
# Limited:limit
# ,:,
# Kotak:kotak
# Mahindra:mahindra
# Bank:bank
# ,:,
# Lakshmi:lakshmi
# Vilas:vila
# Bank:bank
# ,:,
# Oriental:orient
# Bank:bank
# Of:Of
# Commerce:commerc
# ,:,
# Punjab:punjab
# National:nation
# Bank:bank
# ,:,
# The:the
# Bank:bank
# Of:Of
# Rajasthan:rajasthan
# ,:,
# Royal:royal
# Bank:bank
# of:of
# Scotland:scotland
# ,:,
# South:south
# Indian:indian
# Bank:bank
# ,:,
# State:state
# Bank:bank
# Of:Of
# India:india
# ,:,
# State:state
# Bank:bank
# of:of
# Indore:indor
# ,:,
# State:state
# Bank:bank
# of:of
# Hyderabad:hyderabad
# ,:,
# State:state
# Bank:bank
# of:of
# Travancore:travancor
# ,:,
# Syndicate:syndic
# Bank:bank
# ,:,
# Tamilnad:tamilnad
# Mercantile:mercantil
# Bank:bank
# Ltd.:ltd.
# ,:,
# Union:union
# Bank:bank
# Of:Of
# India:india
# ,:,
# Vijaya:vijaya
# Bank:bank
# ,:,
# Yes:ye
# Bank:bank
# You:you
# can:can
# also:also
# pay:pay
# through:through
# Cash:cash
# On:On
# Delivery:deliveri
# (:(
# C-O-D:c-o-d
# ):)
# -:-
# You:you
# can:can
# also:also
# pay:pay
# through:through
# Cash:cash
# On:On
# Delivery:deliveri
# (:(
# COD:cod
# ):)
# .:.
# In:In
# this:thi
# case:case
# you:you
# pay:pay
# in:in
# Cash:cash
# to:to
# the:the
# courier:courier
# person:person
# while:while
# accepting:accept
# the:the
# goods:good
# .:.
# COD:cod
# payments:payment
# would:would
# be:be
# accepted:accept
# for:for
# orders:order
# with:with
# total:total
# invoice:invoic
# value:valu
# greater:greater
# than:than
# equal:equal
# to:to
# Rs:Rs
# .:.
# 499/-:499/-
# and:and
# up:up
# to:to
# Rs:Rs
# .:.
# 15,000/-:15,000/-
# .:.

# %% [markdown]
# lemmatisation

# %%
from nltk.stem import WordNetLemmatizer

lemmatiser = WordNetLemmatizer()

for sentence in text:
    words = word_tokenize(sentence)
    for word in words:
        print(word + ":" + ps.stem(word))
        print("Lemmatise %s: %s" % (word, lemmatiser.lemmatize(word)))
        print("Lemmatise %s: %s" % (word, lemmatiser.lemmatize(word, pos="v")))
# Out:
# What:what
# Lemmatise What: What
# Lemmatise What: What
# is:is
# Lemmatise is: is
# Lemmatise is: be
# Firstcry:firstcri
# Lemmatise Firstcry: Firstcry
# Lemmatise Firstcry: Firstcry
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# Firstcry:firstcri
# Lemmatise Firstcry: Firstcry
# Lemmatise Firstcry: Firstcry
# is:is
# Lemmatise is: is
# Lemmatise is: be
# Asia:asia
# Lemmatise Asia: Asia
# Lemmatise Asia: Asia
# 's:'s
# Lemmatise 's: 's
# Lemmatise 's: 's
# largest:largest
# Lemmatise largest: largest
# Lemmatise largest: largest
# online:onlin
# Lemmatise online: online
# Lemmatise online: online
# store:store
# Lemmatise store: store
# Lemmatise store: store
# for:for
# Lemmatise for: for
# Lemmatise for: for
# baby:babi
# Lemmatise baby: baby
# Lemmatise baby: baby
# and:and
# Lemmatise and: and
# Lemmatise and: and
# kids:kid
# Lemmatise kids: kid
# Lemmatise kids: kid
# products:product
# Lemmatise products: product
# Lemmatise products: products
# .:.
# Lemmatise .: .
# Lemmatise .: .
# We:We
# Lemmatise We: We
# Lemmatise We: We
# cater:cater
# Lemmatise cater: cater
# Lemmatise cater: cater
# to:to
# Lemmatise to: to
# Lemmatise to: to
# the:the
# Lemmatise the: the
# Lemmatise the: the
# needs:need
# Lemmatise needs: need
# Lemmatise needs: need
# of:of
# Lemmatise of: of
# Lemmatise of: of
# our:our
# Lemmatise our: our
# Lemmatise our: our
# buyers:buyer
# Lemmatise buyers: buyer
# Lemmatise buyers: buyers
# (:(
# Lemmatise (: (
# Lemmatise (: (
# mothers:mother
# Lemmatise mothers: mother
# Lemmatise mothers: mother
# buying:buy
# Lemmatise buying: buying
# Lemmatise buying: buy
# for:for
# Lemmatise for: for
# Lemmatise for: for
# their:their
# Lemmatise their: their
# Lemmatise their: their
# kids:kid
# Lemmatise kids: kid
# Lemmatise kids: kid
# ):)
# Lemmatise ): )
# Lemmatise ): )
# from:from
# Lemmatise from: from
# Lemmatise from: from
# before:befor
# Lemmatise before: before
# Lemmatise before: before
# the:the
# Lemmatise the: the
# Lemmatise the: the
# kid:kid
# Lemmatise kid: kid
# Lemmatise kid: kid
# is:is
# Lemmatise is: is
# Lemmatise is: be
# born:born
# Lemmatise born: born
# Lemmatise born: bear
# upto:upto
# Lemmatise upto: upto
# Lemmatise upto: upto
# his/her:his/her
# Lemmatise his/her: his/her
# Lemmatise his/her: his/her
# early:earli
# Lemmatise early: early
# Lemmatise early: early
# teens:teen
# Lemmatise teens: teen
# Lemmatise teens: teens
# .:.
# Lemmatise .: .
# Lemmatise .: .
# What:what
# Lemmatise What: What
# Lemmatise What: What
# is:is
# Lemmatise is: is
# Lemmatise is: be
# the:the
# Lemmatise the: the
# Lemmatise the: the
# benefit:benefit
# Lemmatise benefit: benefit
# Lemmatise benefit: benefit
# of:of
# Lemmatise of: of
# Lemmatise of: of
# buying:buy
# Lemmatise buying: buying
# Lemmatise buying: buy
# from:from
# Lemmatise from: from
# Lemmatise from: from
# Firstcry:firstcri
# Lemmatise Firstcry: Firstcry
# Lemmatise Firstcry: Firstcry
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# Our:our
# Lemmatise Our: Our
# Lemmatise Our: Our
# company:compani
# Lemmatise company: company
# Lemmatise company: company
# philosophy:philosophi
# Lemmatise philosophy: philosophy
# Lemmatise philosophy: philosophy
# is:is
# Lemmatise is: is
# Lemmatise is: be
# pretty:pretti
# Lemmatise pretty: pretty
# Lemmatise pretty: pretty
# simple:simpl
# Lemmatise simple: simple
# Lemmatise simple: simple
# :::
# Lemmatise :: :
# Lemmatise :: :
# We:We
# Lemmatise We: We
# Lemmatise We: We
# want:want
# Lemmatise want: want
# Lemmatise want: want
# to:to
# Lemmatise to: to
# Lemmatise to: to
# offer:offer
# Lemmatise offer: offer
# Lemmatise offer: offer
# the:the
# Lemmatise the: the
# Lemmatise the: the
# best:best
# Lemmatise best: best
# Lemmatise best: best
# possible:possibl
# Lemmatise possible: possible
# Lemmatise possible: possible
# deal:deal
# Lemmatise deal: deal
# Lemmatise deal: deal
# for:for
# Lemmatise for: for
# Lemmatise for: for
# our:our
# Lemmatise our: our
# Lemmatise our: our
# customers:custom
# Lemmatise customers: customer
# Lemmatise customers: customers
# for:for
# Lemmatise for: for
# Lemmatise for: for
# the:the
# Lemmatise the: the
# Lemmatise the: the
# products:product
# Lemmatise products: product
# Lemmatise products: products
# that:that
# Lemmatise that: that
# Lemmatise that: that
# we:we
# Lemmatise we: we
# Lemmatise we: we
# all:all
# Lemmatise all: all
# Lemmatise all: all
# want:want
# Lemmatise want: want
# Lemmatise want: want
# to:to
# Lemmatise to: to
# Lemmatise to: to
# buy:buy
# Lemmatise buy: buy
# Lemmatise buy: buy
# for:for
# Lemmatise for: for
# Lemmatise for: for
# our:our
# Lemmatise our: our
# Lemmatise our: our
# children:children
# Lemmatise children: child
# Lemmatise children: children
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Our:our
# Lemmatise Our: Our
# Lemmatise Our: Our
# endeavour:endeavour
# Lemmatise endeavour: endeavour
# Lemmatise endeavour: endeavour
# is:is
# Lemmatise is: is
# Lemmatise is: be
# to:to
# Lemmatise to: to
# Lemmatise to: to
# ensure:ensur
# Lemmatise ensure: ensure
# Lemmatise ensure: ensure
# that:that
# Lemmatise that: that
# Lemmatise that: that
# you:you
# Lemmatise you: you
# Lemmatise you: you
# get:get
# Lemmatise get: get
# Lemmatise get: get
# the:the
# Lemmatise the: the
# Lemmatise the: the
# widest:widest
# Lemmatise widest: widest
# Lemmatise widest: widest
# possible:possibl
# Lemmatise possible: possible
# Lemmatise possible: possible
# choice:choic
# Lemmatise choice: choice
# Lemmatise choice: choice
# of:of
# Lemmatise of: of
# Lemmatise of: of
# top:top
# Lemmatise top: top
# Lemmatise top: top
# rated:rate
# Lemmatise rated: rated
# Lemmatise rated: rat
# brands:brand
# Lemmatise brands: brand
# Lemmatise brands: brand
# and:and
# Lemmatise and: and
# Lemmatise and: and
# products:product
# Lemmatise products: product
# Lemmatise products: products
# at:at
# Lemmatise at: at
# Lemmatise at: at
# the:the
# Lemmatise the: the
# Lemmatise the: the
# best:best
# Lemmatise best: best
# Lemmatise best: best
# possible:possibl
# Lemmatise possible: possible
# Lemmatise possible: possible
# price:price
# Lemmatise price: price
# Lemmatise price: price
# anywhere:anywher
# Lemmatise anywhere: anywhere
# Lemmatise anywhere: anywhere
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# combined:combin
# Lemmatise combined: combined
# Lemmatise combined: combine
# with:with
# Lemmatise with: with
# Lemmatise with: with
# best:best
# Lemmatise best: best
# Lemmatise best: best
# possible:possibl
# Lemmatise possible: possible
# Lemmatise possible: possible
# service:servic
# Lemmatise service: service
# Lemmatise service: service
# and:and
# Lemmatise and: and
# Lemmatise and: and
# timely:time
# Lemmatise timely: timely
# Lemmatise timely: timely
# delivery:deliveri
# Lemmatise delivery: delivery
# Lemmatise delivery: delivery
# of:of
# Lemmatise of: of
# Lemmatise of: of
# products:product
# Lemmatise products: product
# Lemmatise products: products
# at:at
# Lemmatise at: at
# Lemmatise at: at
# your:your
# Lemmatise your: your
# Lemmatise your: your
# doorstep:doorstep
# Lemmatise doorstep: doorstep
# Lemmatise doorstep: doorstep
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Where:where
# Lemmatise Where: Where
# Lemmatise Where: Where
# are:are
# Lemmatise are: are
# Lemmatise are: be
# the:the
# Lemmatise the: the
# Lemmatise the: the
# offices:offic
# Lemmatise offices: office
# Lemmatise offices: offices
# of:of
# Lemmatise of: of
# Lemmatise of: of
# FirstCry:firstcri
# Lemmatise FirstCry: FirstCry
# Lemmatise FirstCry: FirstCry
# located:locat
# Lemmatise located: located
# Lemmatise located: locate
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# Currently:current
# Lemmatise Currently: Currently
# Lemmatise Currently: Currently
# our:our
# Lemmatise our: our
# Lemmatise our: our
# office:offic
# Lemmatise office: office
# Lemmatise office: office
# is:is
# Lemmatise is: is
# Lemmatise is: be
# located:locat
# Lemmatise located: located
# Lemmatise located: locate
# in:in
# Lemmatise in: in
# Lemmatise in: in
# Pune:pune
# Lemmatise Pune: Pune
# Lemmatise Pune: Pune
# while:while
# Lemmatise while: while
# Lemmatise while: while
# the:the
# Lemmatise the: the
# Lemmatise the: the
# orders:order
# Lemmatise orders: order
# Lemmatise orders: order
# are:are
# Lemmatise are: are
# Lemmatise are: be
# shipped:ship
# Lemmatise shipped: shipped
# Lemmatise shipped: ship
# from:from
# Lemmatise from: from
# Lemmatise from: from
# our:our
# Lemmatise our: our
# Lemmatise our: our
# warehouses:warehous
# Lemmatise warehouses: warehouse
# Lemmatise warehouses: warehouse
# located:locat
# Lemmatise located: located
# Lemmatise located: locate
# across:across
# Lemmatise across: across
# Lemmatise across: across
# India:india
# Lemmatise India: India
# Lemmatise India: India
# .:.
# Lemmatise .: .
# Lemmatise .: .
# What:what
# Lemmatise What: What
# Lemmatise What: What
# products:product
# Lemmatise products: product
# Lemmatise products: products
# does:doe
# Lemmatise does: doe
# Lemmatise does: do
# Firstcry:firstcri
# Lemmatise Firstcry: Firstcry
# Lemmatise Firstcry: Firstcry
# sell:sell
# Lemmatise sell: sell
# Lemmatise sell: sell
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# sell:sell
# Lemmatise sell: sell
# Lemmatise sell: sell
# products:product
# Lemmatise products: product
# Lemmatise products: products
# of:of
# Lemmatise of: of
# Lemmatise of: of
# all:all
# Lemmatise all: all
# Lemmatise all: all
# the:the
# Lemmatise the: the
# Lemmatise the: the
# leading:lead
# Lemmatise leading: leading
# Lemmatise leading: lead
# brands:brand
# Lemmatise brands: brand
# Lemmatise brands: brand
# for:for
# Lemmatise for: for
# Lemmatise for: for
# babies:babi
# Lemmatise babies: baby
# Lemmatise babies: baby
# and:and
# Lemmatise and: and
# Lemmatise and: and
# kids:kid
# Lemmatise kids: kid
# Lemmatise kids: kid
# across:across
# Lemmatise across: across
# Lemmatise across: across
# sections:section
# Lemmatise sections: section
# Lemmatise sections: section
# right:right
# Lemmatise right: right
# Lemmatise right: right
# from:from
# Lemmatise from: from
# Lemmatise from: from
# diapers:diaper
# Lemmatise diapers: diaper
# Lemmatise diapers: diapers
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# baby:babi
# Lemmatise baby: baby
# Lemmatise baby: baby
# food:food
# Lemmatise food: food
# Lemmatise food: food
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# infant:infant
# Lemmatise infant: infant
# Lemmatise infant: infant
# accessories:accessori
# Lemmatise accessories: accessory
# Lemmatise accessories: accessories
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# gears:gear
# Lemmatise gears: gear
# Lemmatise gears: gear
# (:(
# Lemmatise (: (
# Lemmatise (: (
# strollers:stroller
# Lemmatise strollers: stroller
# Lemmatise strollers: strollers
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# high:high
# Lemmatise high: high
# Lemmatise high: high
# chairs:chair
# Lemmatise chairs: chair
# Lemmatise chairs: chair
# ):)
# Lemmatise ): )
# Lemmatise ): )
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# nursery:nurseri
# Lemmatise nursery: nursery
# Lemmatise nursery: nursery
# furniture:furnitur
# Lemmatise furniture: furniture
# Lemmatise furniture: furniture
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# clothes:cloth
# Lemmatise clothes: clothes
# Lemmatise clothes: clothe
# &:&
# Lemmatise &: &
# Lemmatise &: &
# footwear:footwear
# Lemmatise footwear: footwear
# Lemmatise footwear: footwear
# to:to
# Lemmatise to: to
# Lemmatise to: to
# toys:toy
# Lemmatise toys: toy
# Lemmatise toys: toy
# and:and
# Lemmatise and: and
# Lemmatise and: and
# school:school
# Lemmatise school: school
# Lemmatise school: school
# products:product
# Lemmatise products: product
# Lemmatise products: products
# .:.
# Lemmatise .: .
# Lemmatise .: .
# We:We
# Lemmatise We: We
# Lemmatise We: We
# also:also
# Lemmatise also: also
# Lemmatise also: also
# stock:stock
# Lemmatise stock: stock
# Lemmatise stock: stock
# items:item
# Lemmatise items: item
# Lemmatise items: items
# from:from
# Lemmatise from: from
# Lemmatise from: from
# some:some
# Lemmatise some: some
# Lemmatise some: some
# of:of
# Lemmatise of: of
# Lemmatise of: of
# the:the
# Lemmatise the: the
# Lemmatise the: the
# leading:lead
# Lemmatise leading: leading
# Lemmatise leading: lead
# importers:import
# Lemmatise importers: importer
# Lemmatise importers: importers
# and:and
# Lemmatise and: and
# Lemmatise and: and
# domestic:domest
# Lemmatise domestic: domestic
# Lemmatise domestic: domestic
# manufacturers:manufactur
# Lemmatise manufacturers: manufacturer
# Lemmatise manufacturers: manufacturers
# of:of
# Lemmatise of: of
# Lemmatise of: of
# the:the
# Lemmatise the: the
# Lemmatise the: the
# country:countri
# Lemmatise country: country
# Lemmatise country: country
# .:.
# Lemmatise .: .
# Lemmatise .: .
# The:the
# Lemmatise The: The
# Lemmatise The: The
# items:item
# Lemmatise items: item
# Lemmatise items: items
# undergo:undergo
# Lemmatise undergo: undergo
# Lemmatise undergo: undergo
# a:a
# Lemmatise a: a
# Lemmatise a: a
# thorough:thorough
# Lemmatise thorough: thorough
# Lemmatise thorough: thorough
# check:check
# Lemmatise check: check
# Lemmatise check: check
# by:by
# Lemmatise by: by
# Lemmatise by: by
# our:our
# Lemmatise our: our
# Lemmatise our: our
# QA:QA
# Lemmatise QA: QA
# Lemmatise QA: QA
# team:team
# Lemmatise team: team
# Lemmatise team: team
# before:befor
# Lemmatise before: before
# Lemmatise before: before
# they:they
# Lemmatise they: they
# Lemmatise they: they
# are:are
# Lemmatise are: are
# Lemmatise are: be
# stocked:stock
# Lemmatise stocked: stocked
# Lemmatise stocked: stock
# .:.
# Lemmatise .: .
# Lemmatise .: .
# What:what
# Lemmatise What: What
# Lemmatise What: What
# 's:'s
# Lemmatise 's: 's
# Lemmatise 's: 's
# the:the
# Lemmatise the: the
# Lemmatise the: the
# minimum:minimum
# Lemmatise minimum: minimum
# Lemmatise minimum: minimum
# order:order
# Lemmatise order: order
# Lemmatise order: order
# value:valu
# Lemmatise value: value
# Lemmatise value: value
# required:requir
# Lemmatise required: required
# Lemmatise required: require
# to:to
# Lemmatise to: to
# Lemmatise to: to
# place:place
# Lemmatise place: place
# Lemmatise place: place
# an:an
# Lemmatise an: an
# Lemmatise an: an
# order:order
# Lemmatise order: order
# Lemmatise order: order
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# To:To
# Lemmatise To: To
# Lemmatise To: To
# place:place
# Lemmatise place: place
# Lemmatise place: place
# an:an
# Lemmatise an: an
# Lemmatise an: an
# order:order
# Lemmatise order: order
# Lemmatise order: order
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# a:a
# Lemmatise a: a
# Lemmatise a: a
# minimum:minimum
# Lemmatise minimum: minimum
# Lemmatise minimum: minimum
# order:order
# Lemmatise order: order
# Lemmatise order: order
# value:valu
# Lemmatise value: value
# Lemmatise value: value
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Rs:Rs
# Lemmatise Rs: Rs
# Lemmatise Rs: Rs
# .:.
# Lemmatise .: .
# Lemmatise .: .
# 249:249
# Lemmatise 249: 249
# Lemmatise 249: 249
# or:or
# Lemmatise or: or
# Lemmatise or: or
# more:more
# Lemmatise more: more
# Lemmatise more: more
# is:is
# Lemmatise is: is
# Lemmatise is: be
# required:requir
# Lemmatise required: required
# Lemmatise required: require
# (:(
# Lemmatise (: (
# Lemmatise (: (
# Excluding:exclud
# Lemmatise Excluding: Excluding
# Lemmatise Excluding: Excluding
# COD:cod
# Lemmatise COD: COD
# Lemmatise COD: COD
# charges:charg
# Lemmatise charges: charge
# Lemmatise charges: charge
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Shipping:ship
# Lemmatise Shipping: Shipping
# Lemmatise Shipping: Shipping
# charges:charg
# Lemmatise charges: charge
# Lemmatise charges: charge
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Taxes:tax
# Lemmatise Taxes: Taxes
# Lemmatise Taxes: Taxes
# or:or
# Lemmatise or: or
# Lemmatise or: or
# value:valu
# Lemmatise value: value
# Lemmatise value: value
# reduced:reduc
# Lemmatise reduced: reduced
# Lemmatise reduced: reduce
# after:after
# Lemmatise after: after
# Lemmatise after: after
# application:applic
# Lemmatise application: application
# Lemmatise application: application
# of:of
# Lemmatise of: of
# Lemmatise of: of
# coupons:coupon
# Lemmatise coupons: coupon
# Lemmatise coupons: coupons
# or:or
# Lemmatise or: or
# Lemmatise or: or
# any:ani
# Lemmatise any: any
# Lemmatise any: any
# other:other
# Lemmatise other: other
# Lemmatise other: other
# offer:offer
# Lemmatise offer: offer
# Lemmatise offer: offer
# ):)
# Lemmatise ): )
# Lemmatise ): )
# .:.
# Lemmatise .: .
# Lemmatise .: .
# How:how
# Lemmatise How: How
# Lemmatise How: How
# do:do
# Lemmatise do: do
# Lemmatise do: do
# I:I
# Lemmatise I: I
# Lemmatise I: I
# know:know
# Lemmatise know: know
# Lemmatise know: know
# my:my
# Lemmatise my: my
# Lemmatise my: my
# order:order
# Lemmatise order: order
# Lemmatise order: order
# has:ha
# Lemmatise has: ha
# Lemmatise has: have
# been:been
# Lemmatise been: been
# Lemmatise been: be
# confirmed:confirm
# Lemmatise confirmed: confirmed
# Lemmatise confirmed: confirm
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# After:after
# Lemmatise After: After
# Lemmatise After: After
# checking:check
# Lemmatise checking: checking
# Lemmatise checking: check
# out:out
# Lemmatise out: out
# Lemmatise out: out
# during:dure
# Lemmatise during: during
# Lemmatise during: during
# the:the
# Lemmatise the: the
# Lemmatise the: the
# payment:payment
# Lemmatise payment: payment
# Lemmatise payment: payment
# process:process
# Lemmatise process: process
# Lemmatise process: process
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# you:you
# Lemmatise you: you
# Lemmatise you: you
# will:will
# Lemmatise will: will
# Lemmatise will: will
# get:get
# Lemmatise get: get
# Lemmatise get: get
# a:a
# Lemmatise a: a
# Lemmatise a: a
# confirmation:confirm
# Lemmatise confirmation: confirmation
# Lemmatise confirmation: confirmation
# that:that
# Lemmatise that: that
# Lemmatise that: that
# your:your
# Lemmatise your: your
# Lemmatise your: your
# payment:payment
# Lemmatise payment: payment
# Lemmatise payment: payment
# has:ha
# Lemmatise has: ha
# Lemmatise has: have
# been:been
# Lemmatise been: been
# Lemmatise been: be
# processed:process
# Lemmatise processed: processed
# Lemmatise processed: process
# successfully:success
# Lemmatise successfully: successfully
# Lemmatise successfully: successfully
# .:.
# Lemmatise .: .
# Lemmatise .: .
# You:you
# Lemmatise You: You
# Lemmatise You: You
# will:will
# Lemmatise will: will
# Lemmatise will: will
# also:also
# Lemmatise also: also
# Lemmatise also: also
# get:get
# Lemmatise get: get
# Lemmatise get: get
# a:a
# Lemmatise a: a
# Lemmatise a: a
# mail:mail
# Lemmatise mail: mail
# Lemmatise mail: mail
# in:in
# Lemmatise in: in
# Lemmatise in: in
# your:your
# Lemmatise your: your
# Lemmatise your: your
# registered:regist
# Lemmatise registered: registered
# Lemmatise registered: register
# email:email
# Lemmatise email: email
# Lemmatise email: email
# id:id
# Lemmatise id: id
# Lemmatise id: id
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# along:along
# Lemmatise along: along
# Lemmatise along: along
# with:with
# Lemmatise with: with
# Lemmatise with: with
# an:an
# Lemmatise an: an
# Lemmatise an: an
# SMS:sm
# Lemmatise SMS: SMS
# Lemmatise SMS: SMS
# to:to
# Lemmatise to: to
# Lemmatise to: to
# your:your
# Lemmatise your: your
# Lemmatise your: your
# registered:regist
# Lemmatise registered: registered
# Lemmatise registered: register
# mobile:mobil
# Lemmatise mobile: mobile
# Lemmatise mobile: mobile
# number:number
# Lemmatise number: number
# Lemmatise number: number
# confirming:confirm
# Lemmatise confirming: confirming
# Lemmatise confirming: confirm
# the:the
# Lemmatise the: the
# Lemmatise the: the
# order:order
# Lemmatise order: order
# Lemmatise order: order
# .:.
# Lemmatise .: .
# Lemmatise .: .
# How:how
# Lemmatise How: How
# Lemmatise How: How
# do:do
# Lemmatise do: do
# Lemmatise do: do
# I:I
# Lemmatise I: I
# Lemmatise I: I
# check:check
# Lemmatise check: check
# Lemmatise check: check
# my:my
# Lemmatise my: my
# Lemmatise my: my
# order:order
# Lemmatise order: order
# Lemmatise order: order
# status:statu
# Lemmatise status: status
# Lemmatise status: status
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# will:will
# Lemmatise will: will
# Lemmatise will: will
# ship:ship
# Lemmatise ship: ship
# Lemmatise ship: ship
# your:your
# Lemmatise your: your
# Lemmatise your: your
# package:packag
# Lemmatise package: package
# Lemmatise package: package
# within:within
# Lemmatise within: within
# Lemmatise within: within
# 24:24
# Lemmatise 24: 24
# Lemmatise 24: 24
# hours:hour
# Lemmatise hours: hour
# Lemmatise hours: hours
# of:of
# Lemmatise of: of
# Lemmatise of: of
# receiving:receiv
# Lemmatise receiving: receiving
# Lemmatise receiving: receive
# the:the
# Lemmatise the: the
# Lemmatise the: the
# order:order
# Lemmatise order: order
# Lemmatise order: order
# .:.
# Lemmatise .: .
# Lemmatise .: .
# We:We
# Lemmatise We: We
# Lemmatise We: We
# will:will
# Lemmatise will: will
# Lemmatise will: will
# also:also
# Lemmatise also: also
# Lemmatise also: also
# mail:mail
# Lemmatise mail: mail
# Lemmatise mail: mail
# you:you
# Lemmatise you: you
# Lemmatise you: you
# the:the
# Lemmatise the: the
# Lemmatise the: the
# name:name
# Lemmatise name: name
# Lemmatise name: name
# of:of
# Lemmatise of: of
# Lemmatise of: of
# the:the
# Lemmatise the: the
# Lemmatise the: the
# courier:courier
# Lemmatise courier: courier
# Lemmatise courier: courier
# company:compani
# Lemmatise company: company
# Lemmatise company: company
# and:and
# Lemmatise and: and
# Lemmatise and: and
# the:the
# Lemmatise the: the
# Lemmatise the: the
# tracking:track
# Lemmatise tracking: tracking
# Lemmatise tracking: track
# number:number
# Lemmatise number: number
# Lemmatise number: number
# of:of
# Lemmatise of: of
# Lemmatise of: of
# your:your
# Lemmatise your: your
# Lemmatise your: your
# consignment:consign
# Lemmatise consignment: consignment
# Lemmatise consignment: consignment
# to:to
# Lemmatise to: to
# Lemmatise to: to
# your:your
# Lemmatise your: your
# Lemmatise your: your
# registered:regist
# Lemmatise registered: registered
# Lemmatise registered: register
# email:email
# Lemmatise email: email
# Lemmatise email: email
# address:address
# Lemmatise address: address
# Lemmatise address: address
# .:.
# Lemmatise .: .
# Lemmatise .: .
# You:you
# Lemmatise You: You
# Lemmatise You: You
# will:will
# Lemmatise will: will
# Lemmatise will: will
# receive:receiv
# Lemmatise receive: receive
# Lemmatise receive: receive
# an:an
# Lemmatise an: an
# Lemmatise an: an
# SMS:sm
# Lemmatise SMS: SMS
# Lemmatise SMS: SMS
# about:about
# Lemmatise about: about
# Lemmatise about: about
# the:the
# Lemmatise the: the
# Lemmatise the: the
# same:same
# Lemmatise same: same
# Lemmatise same: same
# .:.
# Lemmatise .: .
# Lemmatise .: .
# In:In
# Lemmatise In: In
# Lemmatise In: In
# case:case
# Lemmatise case: case
# Lemmatise case: case
# you:you
# Lemmatise you: you
# Lemmatise you: you
# do:do
# Lemmatise do: do
# Lemmatise do: do
# not:not
# Lemmatise not: not
# Lemmatise not: not
# receive:receiv
# Lemmatise receive: receive
# Lemmatise receive: receive
# an:an
# Lemmatise an: an
# Lemmatise an: an
# email:email
# Lemmatise email: email
# Lemmatise email: email
# from:from
# Lemmatise from: from
# Lemmatise from: from
# us:us
# Lemmatise us: u
# Lemmatise us: us
# within:within
# Lemmatise within: within
# Lemmatise within: within
# 24:24
# Lemmatise 24: 24
# Lemmatise 24: 24
# hours:hour
# Lemmatise hours: hour
# Lemmatise hours: hours
# of:of
# Lemmatise of: of
# Lemmatise of: of
# placing:place
# Lemmatise placing: placing
# Lemmatise placing: place
# an:an
# Lemmatise an: an
# Lemmatise an: an
# order:order
# Lemmatise order: order
# Lemmatise order: order
# please:pleas
# Lemmatise please: please
# Lemmatise please: please
# check:check
# Lemmatise check: check
# Lemmatise check: check
# your:your
# Lemmatise your: your
# Lemmatise your: your
# spam:spam
# Lemmatise spam: spam
# Lemmatise spam: spam
# folder:folder
# Lemmatise folder: folder
# Lemmatise folder: folder
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Tracking:track
# Lemmatise Tracking: Tracking
# Lemmatise Tracking: Tracking
# may:may
# Lemmatise may: may
# Lemmatise may: may
# not:not
# Lemmatise not: not
# Lemmatise not: not
# appear:appear
# Lemmatise appear: appear
# Lemmatise appear: appear
# online:onlin
# Lemmatise online: online
# Lemmatise online: online
# for:for
# Lemmatise for: for
# Lemmatise for: for
# up:up
# Lemmatise up: up
# Lemmatise up: up
# to:to
# Lemmatise to: to
# Lemmatise to: to
# another:anoth
# Lemmatise another: another
# Lemmatise another: another
# 24:24
# Lemmatise 24: 24
# Lemmatise 24: 24
# hours:hour
# Lemmatise hours: hour
# Lemmatise hours: hours
# in:in
# Lemmatise in: in
# Lemmatise in: in
# some:some
# Lemmatise some: some
# Lemmatise some: some
# cases:case
# Lemmatise cases: case
# Lemmatise cases: case
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# so:so
# Lemmatise so: so
# Lemmatise so: so
# please:pleas
# Lemmatise please: please
# Lemmatise please: please
# wait:wait
# Lemmatise wait: wait
# Lemmatise wait: wait
# until:until
# Lemmatise until: until
# Lemmatise until: until
# your:your
# Lemmatise your: your
# Lemmatise your: your
# package:packag
# Lemmatise package: package
# Lemmatise package: package
# is:is
# Lemmatise is: is
# Lemmatise is: be
# scanned:scan
# Lemmatise scanned: scanned
# Lemmatise scanned: scan
# by:by
# Lemmatise by: by
# Lemmatise by: by
# the:the
# Lemmatise the: the
# Lemmatise the: the
# courier:courier
# Lemmatise courier: courier
# Lemmatise courier: courier
# company:compani
# Lemmatise company: company
# Lemmatise company: company
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Alternatively:altern
# Lemmatise Alternatively: Alternatively
# Lemmatise Alternatively: Alternatively
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# you:you
# Lemmatise you: you
# Lemmatise you: you
# can:can
# Lemmatise can: can
# Lemmatise can: can
# check:check
# Lemmatise check: check
# Lemmatise check: check
# the:the
# Lemmatise the: the
# Lemmatise the: the
# same:same
# Lemmatise same: same
# Lemmatise same: same
# in:in
# Lemmatise in: in
# Lemmatise in: in
# My:My
# Lemmatise My: My
# Lemmatise My: My
# Account:account
# Lemmatise Account: Account
# Lemmatise Account: Account
# page:page
# Lemmatise page: page
# Lemmatise page: page
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# where:where
# Lemmatise where: where
# Lemmatise where: where
# Track:track
# Lemmatise Track: Track
# Lemmatise Track: Track
# Shipment:shipment
# Lemmatise Shipment: Shipment
# Lemmatise Shipment: Shipment
# option:option
# Lemmatise option: option
# Lemmatise option: option
# gives:give
# Lemmatise gives: give
# Lemmatise gives: give
# you:you
# Lemmatise you: you
# Lemmatise you: you
# the:the
# Lemmatise the: the
# Lemmatise the: the
# current:current
# Lemmatise current: current
# Lemmatise current: current
# status:statu
# Lemmatise status: status
# Lemmatise status: status
# of:of
# Lemmatise of: of
# Lemmatise of: of
# your:your
# Lemmatise your: your
# Lemmatise your: your
# order:order
# Lemmatise order: order
# Lemmatise order: order
# being:be
# Lemmatise being: being
# Lemmatise being: be
# shipped:ship
# Lemmatise shipped: shipped
# Lemmatise shipped: ship
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Is:Is
# Lemmatise Is: Is
# Lemmatise Is: Is
# it:it
# Lemmatise it: it
# Lemmatise it: it
# safe:safe
# Lemmatise safe: safe
# Lemmatise safe: safe
# to:to
# Lemmatise to: to
# Lemmatise to: to
# use:use
# Lemmatise use: use
# Lemmatise use: use
# my:my
# Lemmatise my: my
# Lemmatise my: my
# Credit:credit
# Lemmatise Credit: Credit
# Lemmatise Credit: Credit
# Card:card
# Lemmatise Card: Card
# Lemmatise Card: Card
# Online:onlin
# Lemmatise Online: Online
# Lemmatise Online: Online
# at:at
# Lemmatise at: at
# Lemmatise at: at
# Firstcry.com:firstcry.com
# Lemmatise Firstcry.com: Firstcry.com
# Lemmatise Firstcry.com: Firstcry.com
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# accept:accept
# Lemmatise accept: accept
# Lemmatise accept: accept
# VISA:visa
# Lemmatise VISA: VISA
# Lemmatise VISA: VISA
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# MASTER:master
# Lemmatise MASTER: MASTER
# Lemmatise MASTER: MASTER
# and:and
# Lemmatise and: and
# Lemmatise and: and
# AMERICAN:american
# Lemmatise AMERICAN: AMERICAN
# Lemmatise AMERICAN: AMERICAN
# EXPRESS:express
# Lemmatise EXPRESS: EXPRESS
# Lemmatise EXPRESS: EXPRESS
# Credit:credit
# Lemmatise Credit: Credit
# Lemmatise Credit: Credit
# Cards:card
# Lemmatise Cards: Cards
# Lemmatise Cards: Cards
# issued:issu
# Lemmatise issued: issued
# Lemmatise issued: issue
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# and:and
# Lemmatise and: and
# Lemmatise and: and
# we:we
# Lemmatise we: we
# Lemmatise we: we
# accept:accept
# Lemmatise accept: accept
# Lemmatise accept: accept
# Debit:debit
# Lemmatise Debit: Debit
# Lemmatise Debit: Debit
# cards:card
# Lemmatise cards: card
# Lemmatise cards: card
# of:of
# Lemmatise of: of
# Lemmatise of: of
# all:all
# Lemmatise all: all
# Lemmatise all: all
# banks:bank
# Lemmatise banks: bank
# Lemmatise banks: bank
# issued:issu
# Lemmatise issued: issued
# Lemmatise issued: issue
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# .:.
# Lemmatise .: .
# Lemmatise .: .
# International:intern
# Lemmatise International: International
# Lemmatise International: International
# credit/debit:credit/debit
# Lemmatise credit/debit: credit/debit
# Lemmatise credit/debit: credit/debit
# card:card
# Lemmatise card: card
# Lemmatise card: card
# transactions:transact
# Lemmatise transactions: transaction
# Lemmatise transactions: transactions
# are:are
# Lemmatise are: are
# Lemmatise are: be
# also:also
# Lemmatise also: also
# Lemmatise also: also
# accepted:accept
# Lemmatise accepted: accepted
# Lemmatise accepted: accept
# through:through
# Lemmatise through: through
# Lemmatise through: through
# Paypal:paypal
# Lemmatise Paypal: Paypal
# Lemmatise Paypal: Paypal
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# so:so
# Lemmatise so: so
# Lemmatise so: so
# now:now
# Lemmatise now: now
# Lemmatise now: now
# you:you
# Lemmatise you: you
# Lemmatise you: you
# can:can
# Lemmatise can: can
# Lemmatise can: can
# place:place
# Lemmatise place: place
# Lemmatise place: place
# orders:order
# Lemmatise orders: order
# Lemmatise orders: order
# with:with
# Lemmatise with: with
# Lemmatise with: with
# Firstcry:firstcri
# Lemmatise Firstcry: Firstcry
# Lemmatise Firstcry: Firstcry
# from:from
# Lemmatise from: from
# Lemmatise from: from
# outside:outsid
# Lemmatise outside: outside
# Lemmatise outside: outside
# India:india
# Lemmatise India: India
# Lemmatise India: India
# and:and
# Lemmatise and: and
# Lemmatise and: and
# we:we
# Lemmatise we: we
# Lemmatise we: we
# will:will
# Lemmatise will: will
# Lemmatise will: will
# ship:ship
# Lemmatise ship: ship
# Lemmatise ship: ship
# it:it
# Lemmatise it: it
# Lemmatise it: it
# to:to
# Lemmatise to: to
# Lemmatise to: to
# your:your
# Lemmatise your: your
# Lemmatise your: your
# dear:dear
# Lemmatise dear: dear
# Lemmatise dear: dear
# ones:one
# Lemmatise ones: one
# Lemmatise ones: ones
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# .:.
# Lemmatise .: .
# Lemmatise .: .
# All:all
# Lemmatise All: All
# Lemmatise All: All
# your:your
# Lemmatise your: your
# Lemmatise your: your
# transactions:transact
# Lemmatise transactions: transaction
# Lemmatise transactions: transactions
# online:onlin
# Lemmatise online: online
# Lemmatise online: online
# are:are
# Lemmatise are: are
# Lemmatise are: be
# protected:protect
# Lemmatise protected: protected
# Lemmatise protected: protect
# &:&
# Lemmatise &: &
# Lemmatise &: &
# secured:secur
# Lemmatise secured: secured
# Lemmatise secured: secure
# by:by
# Lemmatise by: by
# Lemmatise by: by
# SSL:ssl
# Lemmatise SSL: SSL
# Lemmatise SSL: SSL
# (:(
# Lemmatise (: (
# Lemmatise (: (
# secure:secur
# Lemmatise secure: secure
# Lemmatise secure: secure
# socket:socket
# Lemmatise socket: socket
# Lemmatise socket: socket
# layer:layer
# Lemmatise layer: layer
# Lemmatise layer: layer
# ):)
# Lemmatise ): )
# Lemmatise ): )
# technology:technolog
# Lemmatise technology: technology
# Lemmatise technology: technology
# from:from
# Lemmatise from: from
# Lemmatise from: from
# GoDaddy.com:godaddy.com
# Lemmatise GoDaddy.com: GoDaddy.com
# Lemmatise GoDaddy.com: GoDaddy.com
# .:.
# Lemmatise .: .
# Lemmatise .: .
# It:It
# Lemmatise It: It
# Lemmatise It: It
# encrypts:encrypt
# Lemmatise encrypts: encrypts
# Lemmatise encrypts: encrypt
# your:your
# Lemmatise your: your
# Lemmatise your: your
# credit:credit
# Lemmatise credit: credit
# Lemmatise credit: credit
# card:card
# Lemmatise card: card
# Lemmatise card: card
# and:and
# Lemmatise and: and
# Lemmatise and: and
# relevant:relev
# Lemmatise relevant: relevant
# Lemmatise relevant: relevant
# information:inform
# Lemmatise information: information
# Lemmatise information: information
# during:dure
# Lemmatise during: during
# Lemmatise during: during
# the:the
# Lemmatise the: the
# Lemmatise the: the
# entire:entir
# Lemmatise entire: entire
# Lemmatise entire: entire
# transaction:transact
# Lemmatise transaction: transaction
# Lemmatise transaction: transaction
# process:process
# Lemmatise process: process
# Lemmatise process: process
# .:.
# Lemmatise .: .
# Lemmatise .: .
# This:thi
# Lemmatise This: This
# Lemmatise This: This
# encryption:encrypt
# Lemmatise encryption: encryption
# Lemmatise encryption: encryption
# makes:make
# Lemmatise makes: make
# Lemmatise makes: make
# your:your
# Lemmatise your: your
# Lemmatise your: your
# shopping:shop
# Lemmatise shopping: shopping
# Lemmatise shopping: shop
# experience:experi
# Lemmatise experience: experience
# Lemmatise experience: experience
# safe:safe
# Lemmatise safe: safe
# Lemmatise safe: safe
# and:and
# Lemmatise and: and
# Lemmatise and: and
# secure:secur
# Lemmatise secure: secure
# Lemmatise secure: secure
# .:.
# Lemmatise .: .
# Lemmatise .: .
# What:what
# Lemmatise What: What
# Lemmatise What: What
# if:if
# Lemmatise if: if
# Lemmatise if: if
# an:an
# Lemmatise an: an
# Lemmatise an: an
# item:item
# Lemmatise item: item
# Lemmatise item: item
# is:is
# Lemmatise is: is
# Lemmatise is: be
# out:out
# Lemmatise out: out
# Lemmatise out: out
# of:of
# Lemmatise of: of
# Lemmatise of: of
# stock:stock
# Lemmatise stock: stock
# Lemmatise stock: stock
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# make:make
# Lemmatise make: make
# Lemmatise make: make
# every:everi
# Lemmatise every: every
# Lemmatise every: every
# effort:effort
# Lemmatise effort: effort
# Lemmatise effort: effort
# to:to
# Lemmatise to: to
# Lemmatise to: to
# keep:keep
# Lemmatise keep: keep
# Lemmatise keep: keep
# all:all
# Lemmatise all: all
# Lemmatise all: all
# products:product
# Lemmatise products: product
# Lemmatise products: products
# in:in
# Lemmatise in: in
# Lemmatise in: in
# stock:stock
# Lemmatise stock: stock
# Lemmatise stock: stock
# .:.
# Lemmatise .: .
# Lemmatise .: .
# However:howev
# Lemmatise However: However
# Lemmatise However: However
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# there:there
# Lemmatise there: there
# Lemmatise there: there
# may:may
# Lemmatise may: may
# Lemmatise may: may
# be:be
# Lemmatise be: be
# Lemmatise be: be
# times:time
# Lemmatise times: time
# Lemmatise times: time
# when:when
# Lemmatise when: when
# Lemmatise when: when
# unexpected:unexpect
# Lemmatise unexpected: unexpected
# Lemmatise unexpected: unexpected
# demands:demand
# Lemmatise demands: demand
# Lemmatise demands: demand
# exceed:exceed
# Lemmatise exceed: exceed
# Lemmatise exceed: exceed
# our:our
# Lemmatise our: our
# Lemmatise our: our
# supply:suppli
# Lemmatise supply: supply
# Lemmatise supply: supply
# .:.
# Lemmatise .: .
# Lemmatise .: .
# We:We
# Lemmatise We: We
# Lemmatise We: We
# will:will
# Lemmatise will: will
# Lemmatise will: will
# notify:notifi
# Lemmatise notify: notify
# Lemmatise notify: notify
# you:you
# Lemmatise you: you
# Lemmatise you: you
# at:at
# Lemmatise at: at
# Lemmatise at: at
# the:the
# Lemmatise the: the
# Lemmatise the: the
# time:time
# Lemmatise time: time
# Lemmatise time: time
# of:of
# Lemmatise of: of
# Lemmatise of: of
# check:check
# Lemmatise check: check
# Lemmatise check: check
# out:out
# Lemmatise out: out
# Lemmatise out: out
# if:if
# Lemmatise if: if
# Lemmatise if: if
# the:the
# Lemmatise the: the
# Lemmatise the: the
# item:item
# Lemmatise item: item
# Lemmatise item: item
# selected:select
# Lemmatise selected: selected
# Lemmatise selected: select
# is:is
# Lemmatise is: is
# Lemmatise is: be
# not:not
# Lemmatise not: not
# Lemmatise not: not
# in:in
# Lemmatise in: in
# Lemmatise in: in
# stock:stock
# Lemmatise stock: stock
# Lemmatise stock: stock
# .:.
# Lemmatise .: .
# Lemmatise .: .
# In:In
# Lemmatise In: In
# Lemmatise In: In
# the:the
# Lemmatise the: the
# Lemmatise the: the
# rare:rare
# Lemmatise rare: rare
# Lemmatise rare: rare
# circumstance:circumst
# Lemmatise circumstance: circumstance
# Lemmatise circumstance: circumstance
# where:where
# Lemmatise where: where
# Lemmatise where: where
# the:the
# Lemmatise the: the
# Lemmatise the: the
# order:order
# Lemmatise order: order
# Lemmatise order: order
# has:ha
# Lemmatise has: ha
# Lemmatise has: have
# been:been
# Lemmatise been: been
# Lemmatise been: be
# accepted:accept
# Lemmatise accepted: accepted
# Lemmatise accepted: accept
# and:and
# Lemmatise and: and
# Lemmatise and: and
# due:due
# Lemmatise due: due
# Lemmatise due: due
# to:to
# Lemmatise to: to
# Lemmatise to: to
# some:some
# Lemmatise some: some
# Lemmatise some: some
# reasons:reason
# Lemmatise reasons: reason
# Lemmatise reasons: reason
# we:we
# Lemmatise we: we
# Lemmatise we: we
# are:are
# Lemmatise are: are
# Lemmatise are: be
# not:not
# Lemmatise not: not
# Lemmatise not: not
# able:abl
# Lemmatise able: able
# Lemmatise able: able
# to:to
# Lemmatise to: to
# Lemmatise to: to
# ship:ship
# Lemmatise ship: ship
# Lemmatise ship: ship
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# we:we
# Lemmatise we: we
# Lemmatise we: we
# will:will
# Lemmatise will: will
# Lemmatise will: will
# notify:notifi
# Lemmatise notify: notify
# Lemmatise notify: notify
# you:you
# Lemmatise you: you
# Lemmatise you: you
# within:within
# Lemmatise within: within
# Lemmatise within: within
# 24:24
# Lemmatise 24: 24
# Lemmatise 24: 24
# hours:hour
# Lemmatise hours: hour
# Lemmatise hours: hours
# and:and
# Lemmatise and: and
# Lemmatise and: and
# the:the
# Lemmatise the: the
# Lemmatise the: the
# money:money
# Lemmatise money: money
# Lemmatise money: money
# will:will
# Lemmatise will: will
# Lemmatise will: will
# be:be
# Lemmatise be: be
# Lemmatise be: be
# returned:return
# Lemmatise returned: returned
# Lemmatise returned: return
# to:to
# Lemmatise to: to
# Lemmatise to: to
# you:you
# Lemmatise you: you
# Lemmatise you: you
# in:in
# Lemmatise in: in
# Lemmatise in: in
# the:the
# Lemmatise the: the
# Lemmatise the: the
# same:same
# Lemmatise same: same
# Lemmatise same: same
# mode:mode
# Lemmatise mode: mode
# Lemmatise mode: mode
# by:by
# Lemmatise by: by
# Lemmatise by: by
# which:which
# Lemmatise which: which
# Lemmatise which: which
# the:the
# Lemmatise the: the
# Lemmatise the: the
# payment:payment
# Lemmatise payment: payment
# Lemmatise payment: payment
# was:wa
# Lemmatise was: wa
# Lemmatise was: be
# made:made
# Lemmatise made: made
# Lemmatise made: make
# within:within
# Lemmatise within: within
# Lemmatise within: within
# 10:10
# Lemmatise 10: 10
# Lemmatise 10: 10
# working:work
# Lemmatise working: working
# Lemmatise working: work
# days:day
# Lemmatise days: day
# Lemmatise days: days
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Some:some
# Lemmatise Some: Some
# Lemmatise Some: Some
# items:item
# Lemmatise items: item
# Lemmatise items: items
# (:(
# Lemmatise (: (
# Lemmatise (: (
# which:which
# Lemmatise which: which
# Lemmatise which: which
# are:are
# Lemmatise are: are
# Lemmatise are: be
# restocked:restock
# Lemmatise restocked: restocked
# Lemmatise restocked: restock
# regularly:regularli
# Lemmatise regularly: regularly
# Lemmatise regularly: regularly
# ):)
# Lemmatise ): )
# Lemmatise ): )
# and:and
# Lemmatise and: and
# Lemmatise and: and
# is:is
# Lemmatise is: is
# Lemmatise is: be
# temporarily:temporarili
# Lemmatise temporarily: temporarily
# Lemmatise temporarily: temporarily
# out:out
# Lemmatise out: out
# Lemmatise out: out
# of:of
# Lemmatise of: of
# Lemmatise of: of
# stock:stock
# Lemmatise stock: stock
# Lemmatise stock: stock
# may:may
# Lemmatise may: may
# Lemmatise may: may
# appear:appear
# Lemmatise appear: appear
# Lemmatise appear: appear
# on:on
# Lemmatise on: on
# Lemmatise on: on
# display:display
# Lemmatise display: display
# Lemmatise display: display
# with:with
# Lemmatise with: with
# Lemmatise with: with
# an:an
# Lemmatise an: an
# Lemmatise an: an
# out:out
# Lemmatise out: out
# Lemmatise out: out
# of:of
# Lemmatise of: of
# Lemmatise of: of
# stock:stock
# Lemmatise stock: stock
# Lemmatise stock: stock
# tag:tag
# Lemmatise tag: tag
# Lemmatise tag: tag
# .:.
# Lemmatise .: .
# Lemmatise .: .
# You:you
# Lemmatise You: You
# Lemmatise You: You
# can:can
# Lemmatise can: can
# Lemmatise can: can
# use:use
# Lemmatise use: use
# Lemmatise use: use
# the:the
# Lemmatise the: the
# Lemmatise the: the
# Notify:notifi
# Lemmatise Notify: Notify
# Lemmatise Notify: Notify
# Me:Me
# Lemmatise Me: Me
# Lemmatise Me: Me
# option:option
# Lemmatise option: option
# Lemmatise option: option
# and:and
# Lemmatise and: and
# Lemmatise and: and
# we:we
# Lemmatise we: we
# Lemmatise we: we
# will:will
# Lemmatise will: will
# Lemmatise will: will
# inform:inform
# Lemmatise inform: inform
# Lemmatise inform: inform
# you:you
# Lemmatise you: you
# Lemmatise you: you
# once:onc
# Lemmatise once: once
# Lemmatise once: once
# the:the
# Lemmatise the: the
# Lemmatise the: the
# product:product
# Lemmatise product: product
# Lemmatise product: product
# is:is
# Lemmatise is: is
# Lemmatise is: be
# replenished:replenish
# Lemmatise replenished: replenished
# Lemmatise replenished: replenish
# and:and
# Lemmatise and: and
# Lemmatise and: and
# available:avail
# Lemmatise available: available
# Lemmatise available: available
# for:for
# Lemmatise for: for
# Lemmatise for: for
# sale:sale
# Lemmatise sale: sale
# Lemmatise sale: sale
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Are:are
# Lemmatise Are: Are
# Lemmatise Are: Are
# there:there
# Lemmatise there: there
# Lemmatise there: there
# any:ani
# Lemmatise any: any
# Lemmatise any: any
# other:other
# Lemmatise other: other
# Lemmatise other: other
# hidden:hidden
# Lemmatise hidden: hidden
# Lemmatise hidden: hide
# charges:charg
# Lemmatise charges: charge
# Lemmatise charges: charge
# like:like
# Lemmatise like: like
# Lemmatise like: like
# Octroi:octroi
# Lemmatise Octroi: Octroi
# Lemmatise Octroi: Octroi
# or:or
# Lemmatise or: or
# Lemmatise or: or
# Entry:entri
# Lemmatise Entry: Entry
# Lemmatise Entry: Entry
# tax:tax
# Lemmatise tax: tax
# Lemmatise tax: tax
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# You:you
# Lemmatise You: You
# Lemmatise You: You
# will:will
# Lemmatise will: will
# Lemmatise will: will
# get:get
# Lemmatise get: get
# Lemmatise get: get
# the:the
# Lemmatise the: the
# Lemmatise the: the
# final:final
# Lemmatise final: final
# Lemmatise final: final
# price:price
# Lemmatise price: price
# Lemmatise price: price
# during:dure
# Lemmatise during: during
# Lemmatise during: during
# check:check
# Lemmatise check: check
# Lemmatise check: check
# out:out
# Lemmatise out: out
# Lemmatise out: out
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Our:our
# Lemmatise Our: Our
# Lemmatise Our: Our
# prices:price
# Lemmatise prices: price
# Lemmatise prices: price
# are:are
# Lemmatise are: are
# Lemmatise are: be
# all:all
# Lemmatise all: all
# Lemmatise all: all
# inclusive:inclus
# Lemmatise inclusive: inclusive
# Lemmatise inclusive: inclusive
# and:and
# Lemmatise and: and
# Lemmatise and: and
# you:you
# Lemmatise you: you
# Lemmatise you: you
# need:need
# Lemmatise need: need
# Lemmatise need: need
# not:not
# Lemmatise not: not
# Lemmatise not: not
# pay:pay
# Lemmatise pay: pay
# Lemmatise pay: pay
# anything:anyth
# Lemmatise anything: anything
# Lemmatise anything: anything
# extra:extra
# Lemmatise extra: extra
# Lemmatise extra: extra
# .:.
# Lemmatise .: .
# Lemmatise .: .
# How:how
# Lemmatise How: How
# Lemmatise How: How
# are:are
# Lemmatise are: are
# Lemmatise are: be
# the:the
# Lemmatise the: the
# Lemmatise the: the
# products:product
# Lemmatise products: product
# Lemmatise products: products
# packaged:packag
# Lemmatise packaged: packaged
# Lemmatise packaged: package
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# Each:each
# Lemmatise Each: Each
# Lemmatise Each: Each
# of:of
# Lemmatise of: of
# Lemmatise of: of
# the:the
# Lemmatise the: the
# Lemmatise the: the
# individual:individu
# Lemmatise individual: individual
# Lemmatise individual: individual
# products:product
# Lemmatise products: product
# Lemmatise products: products
# are:are
# Lemmatise are: are
# Lemmatise are: be
# securely:secur
# Lemmatise securely: securely
# Lemmatise securely: securely
# packaged:packag
# Lemmatise packaged: packaged
# Lemmatise packaged: package
# in:in
# Lemmatise in: in
# Lemmatise in: in
# bubble:bubbl
# Lemmatise bubble: bubble
# Lemmatise bubble: bubble
# wrap:wrap
# Lemmatise wrap: wrap
# Lemmatise wrap: wrap
# and:and
# Lemmatise and: and
# Lemmatise and: and
# put:put
# Lemmatise put: put
# Lemmatise put: put
# into:into
# Lemmatise into: into
# Lemmatise into: into
# a:a
# Lemmatise a: a
# Lemmatise a: a
# box:box
# Lemmatise box: box
# Lemmatise box: box
# .:.
# Lemmatise .: .
# Lemmatise .: .
# The:the
# Lemmatise The: The
# Lemmatise The: The
# box:box
# Lemmatise box: box
# Lemmatise box: box
# is:is
# Lemmatise is: is
# Lemmatise is: be
# sealed:seal
# Lemmatise sealed: sealed
# Lemmatise sealed: seal
# well:well
# Lemmatise well: well
# Lemmatise well: well
# ensuring:ensur
# Lemmatise ensuring: ensuring
# Lemmatise ensuring: ensure
# a:a
# Lemmatise a: a
# Lemmatise a: a
# safe:safe
# Lemmatise safe: safe
# Lemmatise safe: safe
# delivery:deliveri
# Lemmatise delivery: delivery
# Lemmatise delivery: delivery
# to:to
# Lemmatise to: to
# Lemmatise to: to
# your:your
# Lemmatise your: your
# Lemmatise your: your
# doorstep:doorstep
# Lemmatise doorstep: doorstep
# Lemmatise doorstep: doorstep
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Do:Do
# Lemmatise Do: Do
# Lemmatise Do: Do
# you:you
# Lemmatise you: you
# Lemmatise you: you
# 'll:'ll
# Lemmatise 'll: 'll
# Lemmatise 'll: 'll
# deliver:deliv
# Lemmatise deliver: deliver
# Lemmatise deliver: deliver
# products:product
# Lemmatise products: product
# Lemmatise products: products
# outside:outsid
# Lemmatise outside: outside
# Lemmatise outside: outside
# India:india
# Lemmatise India: India
# Lemmatise India: India
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# do:do
# Lemmatise do: do
# Lemmatise do: do
# not:not
# Lemmatise not: not
# Lemmatise not: not
# ship:ship
# Lemmatise ship: ship
# Lemmatise ship: ship
# products:product
# Lemmatise products: product
# Lemmatise products: products
# outside:outsid
# Lemmatise outside: outside
# Lemmatise outside: outside
# India:india
# Lemmatise India: India
# Lemmatise India: India
# but:but
# Lemmatise but: but
# Lemmatise but: but
# the:the
# Lemmatise the: the
# Lemmatise the: the
# site:site
# Lemmatise site: site
# Lemmatise site: site
# is:is
# Lemmatise is: is
# Lemmatise is: be
# accessible:access
# Lemmatise accessible: accessible
# Lemmatise accessible: accessible
# to:to
# Lemmatise to: to
# Lemmatise to: to
# all:all
# Lemmatise all: all
# Lemmatise all: all
# and:and
# Lemmatise and: and
# Lemmatise and: and
# we:we
# Lemmatise we: we
# Lemmatise we: we
# do:do
# Lemmatise do: do
# Lemmatise do: do
# take:take
# Lemmatise take: take
# Lemmatise take: take
# orders:order
# Lemmatise orders: order
# Lemmatise orders: order
# from:from
# Lemmatise from: from
# Lemmatise from: from
# around:around
# Lemmatise around: around
# Lemmatise around: around
# the:the
# Lemmatise the: the
# Lemmatise the: the
# world:world
# Lemmatise world: world
# Lemmatise world: world
# provided:provid
# Lemmatise provided: provided
# Lemmatise provided: provide
# the:the
# Lemmatise the: the
# Lemmatise the: the
# shipping:ship
# Lemmatise shipping: shipping
# Lemmatise shipping: ship
# address:address
# Lemmatise address: address
# Lemmatise address: address
# is:is
# Lemmatise is: is
# Lemmatise is: be
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# .:.
# Lemmatise .: .
# Lemmatise .: .
# Is:Is
# Lemmatise Is: Is
# Lemmatise Is: Is
# it:it
# Lemmatise it: it
# Lemmatise it: it
# mandatory:mandatori
# Lemmatise mandatory: mandatory
# Lemmatise mandatory: mandatory
# to:to
# Lemmatise to: to
# Lemmatise to: to
# register:regist
# Lemmatise register: register
# Lemmatise register: register
# before:befor
# Lemmatise before: before
# Lemmatise before: before
# placing:place
# Lemmatise placing: placing
# Lemmatise placing: place
# an:an
# Lemmatise an: an
# Lemmatise an: an
# order:order
# Lemmatise order: order
# Lemmatise order: order
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# You:you
# Lemmatise You: You
# Lemmatise You: You
# can:can
# Lemmatise can: can
# Lemmatise can: can
# place:place
# Lemmatise place: place
# Lemmatise place: place
# your:your
# Lemmatise your: your
# Lemmatise your: your
# order:order
# Lemmatise order: order
# Lemmatise order: order
# by:by
# Lemmatise by: by
# Lemmatise by: by
# just:just
# Lemmatise just: just
# Lemmatise just: just
# providing:provid
# Lemmatise providing: providing
# Lemmatise providing: provide
# us:us
# Lemmatise us: u
# Lemmatise us: us
# with:with
# Lemmatise with: with
# Lemmatise with: with
# your:your
# Lemmatise your: your
# Lemmatise your: your
# email:email
# Lemmatise email: email
# Lemmatise email: email
# address:address
# Lemmatise address: address
# Lemmatise address: address
# .:.
# Lemmatise .: .
# Lemmatise .: .
# However:howev
# Lemmatise However: However
# Lemmatise However: However
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# it:it
# Lemmatise it: it
# Lemmatise it: it
# is:is
# Lemmatise is: is
# Lemmatise is: be
# recommended:recommend
# Lemmatise recommended: recommended
# Lemmatise recommended: recommend
# that:that
# Lemmatise that: that
# Lemmatise that: that
# you:you
# Lemmatise you: you
# Lemmatise you: you
# register:regist
# Lemmatise register: register
# Lemmatise register: register
# with:with
# Lemmatise with: with
# Lemmatise with: with
# us:us
# Lemmatise us: u
# Lemmatise us: us
# in:in
# Lemmatise in: in
# Lemmatise in: in
# order:order
# Lemmatise order: order
# Lemmatise order: order
# to:to
# Lemmatise to: to
# Lemmatise to: to
# receive:receiv
# Lemmatise receive: receive
# Lemmatise receive: receive
# timely:time
# Lemmatise timely: timely
# Lemmatise timely: timely
# offers:offer
# Lemmatise offers: offer
# Lemmatise offers: offer
# and:and
# Lemmatise and: and
# Lemmatise and: and
# also:also
# Lemmatise also: also
# Lemmatise also: also
# to:to
# Lemmatise to: to
# Lemmatise to: to
# maintain:maintain
# Lemmatise maintain: maintain
# Lemmatise maintain: maintain
# your:your
# Lemmatise your: your
# Lemmatise your: your
# Wishlist:wishlist
# Lemmatise Wishlist: Wishlist
# Lemmatise Wishlist: Wishlist
# and:and
# Lemmatise and: and
# Lemmatise and: and
# account:account
# Lemmatise account: account
# Lemmatise account: account
# &:&
# Lemmatise &: &
# Lemmatise &: &
# address:address
# Lemmatise address: address
# Lemmatise address: address
# details:detail
# Lemmatise details: detail
# Lemmatise details: detail
# .:.
# Lemmatise .: .
# Lemmatise .: .
# How:how
# Lemmatise How: How
# Lemmatise How: How
# long:long
# Lemmatise long: long
# Lemmatise long: long
# will:will
# Lemmatise will: will
# Lemmatise will: will
# it:it
# Lemmatise it: it
# Lemmatise it: it
# take:take
# Lemmatise take: take
# Lemmatise take: take
# to:to
# Lemmatise to: to
# Lemmatise to: to
# receive:receiv
# Lemmatise receive: receive
# Lemmatise receive: receive
# my:my
# Lemmatise my: my
# Lemmatise my: my
# orders:order
# Lemmatise orders: order
# Lemmatise orders: order
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# ...
# Policy:polici
# Lemmatise Policy: Policy
# Lemmatise Policy: Policy
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# have:have
# Lemmatise have: have
# Lemmatise have: have
# a:a
# Lemmatise a: a
# Lemmatise a: a
# 30:30
# Lemmatise 30: 30
# Lemmatise 30: 30
# days:day
# Lemmatise days: day
# Lemmatise days: days
# return:return
# Lemmatise return: return
# Lemmatise return: return
# policy:polici
# Lemmatise policy: policy
# Lemmatise policy: policy
# for:for
# Lemmatise for: for
# Lemmatise for: for
# Clothes:cloth
# Lemmatise Clothes: Clothes
# Lemmatise Clothes: Clothes
# &:&
# Lemmatise &: &
# Lemmatise &: &
# Footwear:footwear
# Lemmatise Footwear: Footwear
# Lemmatise Footwear: Footwear
# and:and
# Lemmatise and: and
# Lemmatise and: and
# a:a
# Lemmatise a: a
# Lemmatise a: a
# 7:7
# Lemmatise 7: 7
# Lemmatise 7: 7
# days:day
# Lemmatise days: day
# Lemmatise days: days
# return:return
# Lemmatise return: return
# Lemmatise return: return
# policy:polici
# Lemmatise policy: policy
# Lemmatise policy: policy
# for:for
# Lemmatise for: for
# Lemmatise for: for
# all:all
# Lemmatise all: all
# Lemmatise all: all
# other:other
# Lemmatise other: other
# Lemmatise other: other
# items:item
# Lemmatise items: item
# Lemmatise items: items
# except:except
# Lemmatise except: except
# Lemmatise except: except
# for:for
# Lemmatise for: for
# Lemmatise for: for
# Personal:person
# Lemmatise Personal: Personal
# Lemmatise Personal: Personal
# Products:product
# Lemmatise Products: Products
# Lemmatise Products: Products
# such:such
# Lemmatise such: such
# Lemmatise such: such
# as:as
# Lemmatise as: a
# Lemmatise as: as
# Diapers:diaper
# Lemmatise Diapers: Diapers
# Lemmatise Diapers: Diapers
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Wipes:wipe
# Lemmatise Wipes: Wipes
# Lemmatise Wipes: Wipes
# and:and
# Lemmatise and: and
# Lemmatise and: and
# Creams:cream
# Lemmatise Creams: Creams
# Lemmatise Creams: Creams
# .:.
# Lemmatise .: .
# Lemmatise .: .
# What:what
# Lemmatise What: What
# Lemmatise What: What
# options:option
# Lemmatise options: option
# Lemmatise options: options
# do:do
# Lemmatise do: do
# Lemmatise do: do
# I:I
# Lemmatise I: I
# Lemmatise I: I
# have:have
# Lemmatise have: have
# Lemmatise have: have
# while:while
# Lemmatise while: while
# Lemmatise while: while
# making:make
# Lemmatise making: making
# Lemmatise making: make
# payment:payment
# Lemmatise payment: payment
# Lemmatise payment: payment
# ?:?
# Lemmatise ?: ?
# Lemmatise ?: ?
# We:We
# Lemmatise We: We
# Lemmatise We: We
# accept:accept
# Lemmatise accept: accept
# Lemmatise accept: accept
# payments:payment
# Lemmatise payments: payment
# Lemmatise payments: payments
# by:by
# Lemmatise by: by
# Lemmatise by: by
# debit:debit
# Lemmatise debit: debit
# Lemmatise debit: debit
# or:or
# Lemmatise or: or
# Lemmatise or: or
# credit:credit
# Lemmatise credit: credit
# Lemmatise credit: credit
# card:card
# Lemmatise card: card
# Lemmatise card: card
# and:and
# Lemmatise and: and
# Lemmatise and: and
# also:also
# Lemmatise also: also
# Lemmatise also: also
# through:through
# Lemmatise through: through
# Lemmatise through: through
# Net:net
# Lemmatise Net: Net
# Lemmatise Net: Net
# Banking.Credit:banking.credit
# Lemmatise Banking.Credit: Banking.Credit
# Lemmatise Banking.Credit: Banking.Credit
# Cards:card
# Lemmatise Cards: Cards
# Lemmatise Cards: Cards
# &:&
# Lemmatise &: &
# Lemmatise &: &
# Debit:debit
# Lemmatise Debit: Debit
# Lemmatise Debit: Debit
# Cards:card
# Lemmatise Cards: Cards
# Lemmatise Cards: Cards
# -:-
# Lemmatise -: -
# Lemmatise -: -
# We:We
# Lemmatise We: We
# Lemmatise We: We
# accept:accept
# Lemmatise accept: accept
# Lemmatise accept: accept
# VISA:visa
# Lemmatise VISA: VISA
# Lemmatise VISA: VISA
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# MASTER:master
# Lemmatise MASTER: MASTER
# Lemmatise MASTER: MASTER
# and:and
# Lemmatise and: and
# Lemmatise and: and
# AMERICAN:american
# Lemmatise AMERICAN: AMERICAN
# Lemmatise AMERICAN: AMERICAN
# EXPRESS:express
# Lemmatise EXPRESS: EXPRESS
# Lemmatise EXPRESS: EXPRESS
# Credit:credit
# Lemmatise Credit: Credit
# Lemmatise Credit: Credit
# Cards:card
# Lemmatise Cards: Cards
# Lemmatise Cards: Cards
# issued:issu
# Lemmatise issued: issued
# Lemmatise issued: issue
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# and:and
# Lemmatise and: and
# Lemmatise and: and
# we:we
# Lemmatise we: we
# Lemmatise we: we
# accept:accept
# Lemmatise accept: accept
# Lemmatise accept: accept
# Debit:debit
# Lemmatise Debit: Debit
# Lemmatise Debit: Debit
# cards:card
# Lemmatise cards: card
# Lemmatise cards: card
# of:of
# Lemmatise of: of
# Lemmatise of: of
# all:all
# Lemmatise all: all
# Lemmatise all: all
# banks:bank
# Lemmatise banks: bank
# Lemmatise banks: bank
# issued:issu
# Lemmatise issued: issued
# Lemmatise issued: issue
# in:in
# Lemmatise in: in
# Lemmatise in: in
# India:india
# Lemmatise India: India
# Lemmatise India: India
# .:.
# Lemmatise .: .
# Lemmatise .: .
# International:intern
# Lemmatise International: International
# Lemmatise International: International
# credit/debit:credit/debit
# Lemmatise credit/debit: credit/debit
# Lemmatise credit/debit: credit/debit
# card:card
# Lemmatise card: card
# Lemmatise card: card
# transactions:transact
# Lemmatise transactions: transaction
# Lemmatise transactions: transactions
# are:are
# Lemmatise are: are
# Lemmatise are: be
# also:also
# Lemmatise also: also
# Lemmatise also: also
# accepted:accept
# Lemmatise accepted: accepted
# Lemmatise accepted: accept
# through:through
# Lemmatise through: through
# Lemmatise through: through
# Pay:pay
# Lemmatise Pay: Pay
# Lemmatise Pay: Pay
# pal.Net:pal.net
# Lemmatise pal.Net: pal.Net
# Lemmatise pal.Net: pal.Net
# Banking:bank
# Lemmatise Banking: Banking
# Lemmatise Banking: Banking
# -:-
# Lemmatise -: -
# Lemmatise -: -
# We:We
# Lemmatise We: We
# Lemmatise We: We
# Accept:accept
# Lemmatise Accept: Accept
# Lemmatise Accept: Accept
# Axis:axi
# Lemmatise Axis: Axis
# Lemmatise Axis: Axis
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Baroda:baroda
# Lemmatise Baroda: Baroda
# Lemmatise Baroda: Baroda
# (:(
# Lemmatise (: (
# Lemmatise (: (
# Retail:retail
# Lemmatise Retail: Retail
# Lemmatise Retail: Retail
# &:&
# Lemmatise &: &
# Lemmatise &: &
# Corporate:corpor
# Lemmatise Corporate: Corporate
# Lemmatise Corporate: Corporate
# Banking:bank
# Lemmatise Banking: Banking
# Lemmatise Banking: Banking
# ):)
# Lemmatise ): )
# Lemmatise ): )
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Of:Of
# Lemmatise Of: Of
# Lemmatise Of: Of
# India:india
# Lemmatise India: India
# Lemmatise India: India
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Maharashtra:maharashtra
# Lemmatise Maharashtra: Maharashtra
# Lemmatise Maharashtra: Maharashtra
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Canara:canara
# Lemmatise Canara: Canara
# Lemmatise Canara: Canara
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Corporation:corpor
# Lemmatise Corporation: Corporation
# Lemmatise Corporation: Corporation
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Citibank:citibank
# Lemmatise Citibank: Citibank
# Lemmatise Citibank: Citibank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Deutsche:deutsch
# Lemmatise Deutsche: Deutsche
# Lemmatise Deutsche: Deutsche
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Federal:feder
# Lemmatise Federal: Federal
# Lemmatise Federal: Federal
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Fed:fed
# Lemmatise Fed: Fed
# Lemmatise Fed: Fed
# Net:net
# Lemmatise Net: Net
# Lemmatise Net: Net
# Banking:bank
# Lemmatise Banking: Banking
# Lemmatise Banking: Banking
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# HDFC:hdfc
# Lemmatise HDFC: HDFC
# Lemmatise HDFC: HDFC
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# ICICI:icici
# Lemmatise ICICI: ICICI
# Lemmatise ICICI: ICICI
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# IDBI:idbi
# Lemmatise IDBI: IDBI
# Lemmatise IDBI: IDBI
# i:i
# Lemmatise i: i
# Lemmatise i: i
# Net:net
# Lemmatise Net: Net
# Lemmatise Net: Net
# Banking:bank
# Lemmatise Banking: Banking
# Lemmatise Banking: Banking
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# IndusInd:indusind
# Lemmatise IndusInd: IndusInd
# Lemmatise IndusInd: IndusInd
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# ING:ing
# Lemmatise ING: ING
# Lemmatise ING: ING
# Vysya:vysya
# Lemmatise Vysya: Vysya
# Lemmatise Vysya: Vysya
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Ltd.:ltd.
# Lemmatise Ltd.: Ltd.
# Lemmatise Ltd.: Ltd.
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Jammu:jammu
# Lemmatise Jammu: Jammu
# Lemmatise Jammu: Jammu
# &:&
# Lemmatise &: &
# Lemmatise &: &
# Kashmir:kashmir
# Lemmatise Kashmir: Kashmir
# Lemmatise Kashmir: Kashmir
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Karnataka:karnataka
# Lemmatise Karnataka: Karnataka
# Lemmatise Karnataka: Karnataka
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Karur:karur
# Lemmatise Karur: Karur
# Lemmatise Karur: Karur
# Vysya:vysya
# Lemmatise Vysya: Vysya
# Lemmatise Vysya: Vysya
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Limited:limit
# Lemmatise Limited: Limited
# Lemmatise Limited: Limited
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Kotak:kotak
# Lemmatise Kotak: Kotak
# Lemmatise Kotak: Kotak
# Mahindra:mahindra
# Lemmatise Mahindra: Mahindra
# Lemmatise Mahindra: Mahindra
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Lakshmi:lakshmi
# Lemmatise Lakshmi: Lakshmi
# Lemmatise Lakshmi: Lakshmi
# Vilas:vila
# Lemmatise Vilas: Vilas
# Lemmatise Vilas: Vilas
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Oriental:orient
# Lemmatise Oriental: Oriental
# Lemmatise Oriental: Oriental
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Of:Of
# Lemmatise Of: Of
# Lemmatise Of: Of
# Commerce:commerc
# Lemmatise Commerce: Commerce
# Lemmatise Commerce: Commerce
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Punjab:punjab
# Lemmatise Punjab: Punjab
# Lemmatise Punjab: Punjab
# National:nation
# Lemmatise National: National
# Lemmatise National: National
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# The:the
# Lemmatise The: The
# Lemmatise The: The
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Of:Of
# Lemmatise Of: Of
# Lemmatise Of: Of
# Rajasthan:rajasthan
# Lemmatise Rajasthan: Rajasthan
# Lemmatise Rajasthan: Rajasthan
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Royal:royal
# Lemmatise Royal: Royal
# Lemmatise Royal: Royal
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Scotland:scotland
# Lemmatise Scotland: Scotland
# Lemmatise Scotland: Scotland
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# South:south
# Lemmatise South: South
# Lemmatise South: South
# Indian:indian
# Lemmatise Indian: Indian
# Lemmatise Indian: Indian
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# State:state
# Lemmatise State: State
# Lemmatise State: State
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Of:Of
# Lemmatise Of: Of
# Lemmatise Of: Of
# India:india
# Lemmatise India: India
# Lemmatise India: India
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# State:state
# Lemmatise State: State
# Lemmatise State: State
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Indore:indor
# Lemmatise Indore: Indore
# Lemmatise Indore: Indore
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# State:state
# Lemmatise State: State
# Lemmatise State: State
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Hyderabad:hyderabad
# Lemmatise Hyderabad: Hyderabad
# Lemmatise Hyderabad: Hyderabad
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# State:state
# Lemmatise State: State
# Lemmatise State: State
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# of:of
# Lemmatise of: of
# Lemmatise of: of
# Travancore:travancor
# Lemmatise Travancore: Travancore
# Lemmatise Travancore: Travancore
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Syndicate:syndic
# Lemmatise Syndicate: Syndicate
# Lemmatise Syndicate: Syndicate
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Tamilnad:tamilnad
# Lemmatise Tamilnad: Tamilnad
# Lemmatise Tamilnad: Tamilnad
# Mercantile:mercantil
# Lemmatise Mercantile: Mercantile
# Lemmatise Mercantile: Mercantile
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Ltd.:ltd.
# Lemmatise Ltd.: Ltd.
# Lemmatise Ltd.: Ltd.
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Union:union
# Lemmatise Union: Union
# Lemmatise Union: Union
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# Of:Of
# Lemmatise Of: Of
# Lemmatise Of: Of
# India:india
# Lemmatise India: India
# Lemmatise India: India
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Vijaya:vijaya
# Lemmatise Vijaya: Vijaya
# Lemmatise Vijaya: Vijaya
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# ,:,
# Lemmatise ,: ,
# Lemmatise ,: ,
# Yes:ye
# Lemmatise Yes: Yes
# Lemmatise Yes: Yes
# Bank:bank
# Lemmatise Bank: Bank
# Lemmatise Bank: Bank
# You:you
# Lemmatise You: You
# Lemmatise You: You
# can:can
# Lemmatise can: can
# Lemmatise can: can
# also:also
# Lemmatise also: also
# Lemmatise also: also
# pay:pay
# Lemmatise pay: pay
# Lemmatise pay: pay
# through:through
# Lemmatise through: through
# Lemmatise through: through
# Cash:cash
# Lemmatise Cash: Cash
# Lemmatise Cash: Cash
# On:On
# Lemmatise On: On
# Lemmatise On: On
# Delivery:deliveri
# Lemmatise Delivery: Delivery
# Lemmatise Delivery: Delivery
# (:(
# Lemmatise (: (
# Lemmatise (: (
# C-O-D:c-o-d
# Lemmatise C-O-D: C-O-D
# Lemmatise C-O-D: C-O-D
# ):)
# Lemmatise ): )
# Lemmatise ): )
# -:-
# Lemmatise -: -
# Lemmatise -: -
# You:you
# Lemmatise You: You
# Lemmatise You: You
# can:can
# Lemmatise can: can
# Lemmatise can: can
# also:also
# Lemmatise also: also
# Lemmatise also: also
# pay:pay
# Lemmatise pay: pay
# Lemmatise pay: pay
# through:through
# Lemmatise through: through
# Lemmatise through: through
# Cash:cash
# Lemmatise Cash: Cash
# Lemmatise Cash: Cash
# On:On
# Lemmatise On: On
# Lemmatise On: On
# Delivery:deliveri
# Lemmatise Delivery: Delivery
# Lemmatise Delivery: Delivery
# (:(
# Lemmatise (: (
# Lemmatise (: (
# COD:cod
# Lemmatise COD: COD
# Lemmatise COD: COD
# ):)
# Lemmatise ): )
# Lemmatise ): )
# .:.
# Lemmatise .: .
# Lemmatise .: .
# In:In
# Lemmatise In: In
# Lemmatise In: In
# this:thi
# Lemmatise this: this
# Lemmatise this: this
# case:case
# Lemmatise case: case
# Lemmatise case: case
# you:you
# Lemmatise you: you
# Lemmatise you: you
# pay:pay
# Lemmatise pay: pay
# Lemmatise pay: pay
# in:in
# Lemmatise in: in
# Lemmatise in: in
# Cash:cash
# Lemmatise Cash: Cash
# Lemmatise Cash: Cash
# to:to
# Lemmatise to: to
# Lemmatise to: to
# the:the
# Lemmatise the: the
# Lemmatise the: the
# courier:courier
# Lemmatise courier: courier
# Lemmatise courier: courier
# person:person
# Lemmatise person: person
# Lemmatise person: person
# while:while
# Lemmatise while: while
# Lemmatise while: while
# accepting:accept
# Lemmatise accepting: accepting
# Lemmatise accepting: accept
# the:the
# Lemmatise the: the
# Lemmatise the: the
# goods:good
# Lemmatise goods: good
# Lemmatise goods: goods
# .:.
# Lemmatise .: .
# Lemmatise .: .
# COD:cod
# Lemmatise COD: COD
# Lemmatise COD: COD
# payments:payment
# Lemmatise payments: payment
# Lemmatise payments: payments
# would:would
# Lemmatise would: would
# Lemmatise would: would
# be:be
# Lemmatise be: be
# Lemmatise be: be
# accepted:accept
# Lemmatise accepted: accepted
# Lemmatise accepted: accept
# for:for
# Lemmatise for: for
# Lemmatise for: for
# orders:order
# Lemmatise orders: order
# Lemmatise orders: order
# with:with
# Lemmatise with: with
# Lemmatise with: with
# total:total
# Lemmatise total: total
# Lemmatise total: total
# invoice:invoic
# Lemmatise invoice: invoice
# Lemmatise invoice: invoice
# value:valu
# Lemmatise value: value
# Lemmatise value: value
# greater:greater
# Lemmatise greater: greater
# Lemmatise greater: greater
# than:than
# Lemmatise than: than
# Lemmatise than: than
# equal:equal
# Lemmatise equal: equal
# Lemmatise equal: equal
# to:to
# Lemmatise to: to
# Lemmatise to: to
# Rs:Rs
# Lemmatise Rs: Rs
# Lemmatise Rs: Rs
# .:.
# Lemmatise .: .
# Lemmatise .: .
# 499/-:499/-
# Lemmatise 499/-: 499/-
# Lemmatise 499/-: 499/-
# and:and
# Lemmatise and: and
# Lemmatise and: and
# up:up
# Lemmatise up: up
# Lemmatise up: up
# to:to
# Lemmatise to: to
# Lemmatise to: to
# Rs:Rs
# Lemmatise Rs: Rs
# Lemmatise Rs: Rs
# .:.
# Lemmatise .: .
# Lemmatise .: .
# 15,000/-:15,000/-
# Lemmatise 15,000/-: 15,000/-
# Lemmatise 15,000/-: 15,000/-
# .:.
# Lemmatise .: .
# Lemmatise .: .

# %%
tw = []
#print(token_words)
for t in token_words:
   tw.append(t.lower())
print(tw)
# Out:
# ['what', 'is', 'firstcry', '?', 'firstcry', 'is', 'asia', "'s", 'largest', 'online', 'store', 'for', 'baby', 'and', 'kids', 'products', '.', 'we', 'cater', 'to', 'the', 'needs', 'of', 'our', 'buyers', '(', 'mothers', 'buying', 'for', 'their', 'kids', ')', 'from', 'before', 'the', 'kid', 'is', 'born', 'upto', 'his/her', 'early', 'teens', '.', 'what', 'is', 'the', 'benefit', 'of', 'buying', 'from', 'firstcry', '?', 'our', 'company', 'philosophy', 'is', 'pretty', 'simple', ':', 'we', 'want', 'to', 'offer', 'the', 'best', 'possible', 'deal', 'for', 'our', 'customers', 'for', 'the', 'products', 'that', 'we', 'all', 'want', 'to', 'buy', 'for', 'our', 'children', '.', 'our', 'endeavour', 'is', 'to', 'ensure', 'that', 'you', 'get', 'the', 'widest', 'possible', 'choice', 'of', 'top', 'rated', 'brands', 'and', 'products', 'at', 'the', 'best', 'possible', 'price', 'anywhere', 'in', 'india', 'combined', 'with', 'best', 'possible', 'service', 'and', 'timely', 'delivery', 'of', 'products', 'at', 'your', 'doorstep', '.', 'where', 'are', 'the', 'offices', 'of', 'firstcry', 'located', '?', 'currently', 'our', 'office', 'is', 'located', 'in', 'pune', 'while', 'the', 'orders', 'are', 'shipped', 'from', 'our', 'warehouses', 'located', 'across', 'india', '.', 'what', 'products', 'does', 'firstcry', 'sell', '?', 'we', 'sell', 'products', 'of', 'all', 'the', 'leading', 'brands', 'for', 'babies', 'and', 'kids', 'across', 'sections', 'right', 'from', 'diapers', ',', 'baby', 'food', ',', 'infant', 'accessories', ',', 'gears', '(', 'strollers', ',', 'high', 'chairs', ')', ',', 'nursery', 'furniture', ',', 'clothes', '&', 'footwear', 'to', 'toys', 'and', 'school', 'products', '.', 'we', 'also', 'stock', 'items', 'from', 'some', 'of', 'the', 'leading', 'importers', 'and', 'domestic', 'manufacturers', 'of', 'the', 'country', '.', 'the', 'items', 'undergo', 'a', 'thorough', 'check', 'by', 'our', 'qa', 'team', 'before', 'they', 'are', 'stocked', '.', 'what', "'s", 'the', 'minimum', 'order', 'value', 'required', 'to', 'place', 'an', 'order', '?', 'to', 'place', 'an', 'order', ',', 'a', 'minimum', 'order', 'value', 'of', 'rs', '.', '249', 'or', 'more', 'is', 'required', '(', 'excluding', 'cod', 'charges', ',', 'shipping', 'charges', ',', 'taxes', 'or', 'value', 'reduced', 'after', 'application', 'of', 'coupons', 'or', 'any', 'other', 'offer', ')', '.', 'how', 'do', 'i', 'know', 'my', 'order', 'has', 'been', 'confirmed', '?', 'after', 'checking', 'out', 'during', 'the', 'payment', 'process', ',', 'you', 'will', 'get', 'a', 'confirmation', 'that', 'your', 'payment', 'has', 'been', 'processed', 'successfully', '.', 'you', 'will', 'also', 'get', 'a', 'mail', 'in', 'your', 'registered', 'email', 'id', ',', 'along', 'with', 'an', 'sms', 'to', 'your', 'registered', 'mobile', 'number', 'confirming', 'the', 'order', '.', 'how', 'do', 'i', 'check', 'my', 'order', 'status', '?', 'we', 'will', 'ship', 'your', 'package', 'within', '24', 'hours', 'of', 'receiving', 'the', 'order', '.', 'we', 'will', 'also', 'mail', 'you', 'the', 'name', 'of', 'the', 'courier', 'company', 'and', 'the', 'tracking', 'number', 'of', 'your', 'consignment', 'to', 'your', 'registered', 'email', 'address', '.', 'you', 'will', 'receive', 'an', 'sms', 'about', 'the', 'same', '.', 'in', 'case', 'you', 'do', 'not', 'receive', 'an', 'email', 'from', 'us', 'within', '24', 'hours', 'of', 'placing', 'an', 'order', 'please', 'check', 'your', 'spam', 'folder', '.', 'tracking', 'may', 'not', 'appear', 'online', 'for', 'up', 'to', 'another', '24', 'hours', 'in', 'some', 'cases', ',', 'so', 'please', 'wait', 'until', 'your', 'package', 'is', 'scanned', 'by', 'the', 'courier', 'company', '.', 'alternatively', ',', 'you', 'can', 'check', 'the', 'same', 'in', 'my', 'account', 'page', ',', 'where', 'track', 'shipment', 'option', 'gives', 'you', 'the', 'current', 'status', 'of', 'your', 'order', 'being', 'shipped', '.', 'is', 'it', 'safe', 'to', 'use', 'my', 'credit', 'card', 'online', 'at', 'firstcry.com', '?', 'we ...

# %% [markdown]
# remove stop words

# %%
from nltk.corpus import stopwords 
stop_words = set(stopwords.words('english'))
filtered_sentence = [w for w in token_words if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in token_words: 
    if w not in stop_words: 
        filtered_sentence.append(w) 


print(token_words)
filtered_sentence_lower = [x.lower() for x in filtered_sentence]
print(filtered_sentence_lower)
# Out:
# ['What', 'is', 'Firstcry', '?', 'Firstcry', 'is', 'Asia', "'s", 'largest', 'online', 'store', 'for', 'baby', 'and', 'kids', 'products', '.', 'We', 'cater', 'to', 'the', 'needs', 'of', 'our', 'buyers', '(', 'mothers', 'buying', 'for', 'their', 'kids', ')', 'from', 'before', 'the', 'kid', 'is', 'born', 'upto', 'his/her', 'early', 'teens', '.', 'What', 'is', 'the', 'benefit', 'of', 'buying', 'from', 'Firstcry', '?', 'Our', 'company', 'philosophy', 'is', 'pretty', 'simple', ':', 'We', 'want', 'to', 'offer', 'the', 'best', 'possible', 'deal', 'for', 'our', 'customers', 'for', 'the', 'products', 'that', 'we', 'all', 'want', 'to', 'buy', 'for', 'our', 'children', '.', 'Our', 'endeavour', 'is', 'to', 'ensure', 'that', 'you', 'get', 'the', 'widest', 'possible', 'choice', 'of', 'top', 'rated', 'brands', 'and', 'products', 'at', 'the', 'best', 'possible', 'price', 'anywhere', 'in', 'India', 'combined', 'with', 'best', 'possible', 'service', 'and', 'timely', 'delivery', 'of', 'products', 'at', 'your', 'doorstep', '.', 'Where', 'are', 'the', 'offices', 'of', 'FirstCry', 'located', '?', 'Currently', 'our', 'office', 'is', 'located', 'in', 'Pune', 'while', 'the', 'orders', 'are', 'shipped', 'from', 'our', 'warehouses', 'located', 'across', 'India', '.', 'What', 'products', 'does', 'Firstcry', 'sell', '?', 'We', 'sell', 'products', 'of', 'all', 'the', 'leading', 'brands', 'for', 'babies', 'and', 'kids', 'across', 'sections', 'right', 'from', 'diapers', ',', 'baby', 'food', ',', 'infant', 'accessories', ',', 'gears', '(', 'strollers', ',', 'high', 'chairs', ')', ',', 'nursery', 'furniture', ',', 'clothes', '&', 'footwear', 'to', 'toys', 'and', 'school', 'products', '.', 'We', 'also', 'stock', 'items', 'from', 'some', 'of', 'the', 'leading', 'importers', 'and', 'domestic', 'manufacturers', 'of', 'the', 'country', '.', 'The', 'items', 'undergo', 'a', 'thorough', 'check', 'by', 'our', 'QA', 'team', 'before', 'they', 'are', 'stocked', '.', 'What', "'s", 'the', 'minimum', 'order', 'value', 'required', 'to', 'place', 'an', 'order', '?', 'To', 'place', 'an', 'order', ',', 'a', 'minimum', 'order', 'value', 'of', 'Rs', '.', '249', 'or', 'more', 'is', 'required', '(', 'Excluding', 'COD', 'charges', ',', 'Shipping', 'charges', ',', 'Taxes', 'or', 'value', 'reduced', 'after', 'application', 'of', 'coupons', 'or', 'any', 'other', 'offer', ')', '.', 'How', 'do', 'I', 'know', 'my', 'order', 'has', 'been', 'confirmed', '?', 'After', 'checking', 'out', 'during', 'the', 'payment', 'process', ',', 'you', 'will', 'get', 'a', 'confirmation', 'that', 'your', 'payment', 'has', 'been', 'processed', 'successfully', '.', 'You', 'will', 'also', 'get', 'a', 'mail', 'in', 'your', 'registered', 'email', 'id', ',', 'along', 'with', 'an', 'SMS', 'to', 'your', 'registered', 'mobile', 'number', 'confirming', 'the', 'order', '.', 'How', 'do', 'I', 'check', 'my', 'order', 'status', '?', 'We', 'will', 'ship', 'your', 'package', 'within', '24', 'hours', 'of', 'receiving', 'the', 'order', '.', 'We', 'will', 'also', 'mail', 'you', 'the', 'name', 'of', 'the', 'courier', 'company', 'and', 'the', 'tracking', 'number', 'of', 'your', 'consignment', 'to', 'your', 'registered', 'email', 'address', '.', 'You', 'will', 'receive', 'an', 'SMS', 'about', 'the', 'same', '.', 'In', 'case', 'you', 'do', 'not', 'receive', 'an', 'email', 'from', 'us', 'within', '24', 'hours', 'of', 'placing', 'an', 'order', 'please', 'check', 'your', 'spam', 'folder', '.', 'Tracking', 'may', 'not', 'appear', 'online', 'for', 'up', 'to', 'another', '24', 'hours', 'in', 'some', 'cases', ',', 'so', 'please', 'wait', 'until', 'your', 'package', 'is', 'scanned', 'by', 'the', 'courier', 'company', '.', 'Alternatively', ',', 'you', 'can', 'check', 'the', 'same', 'in', 'My', 'Account', 'page', ',', 'where', 'Track', 'Shipment', 'option', 'gives', 'you', 'the', 'current', 'status', 'of', 'your', 'order', 'being', 'shipped', '.', 'Is', 'it', 'safe', 'to', 'use', 'my', 'Credit', 'Card', 'Online', 'at', 'Firstcry.com', '?', 'We ...
# ['what', 'firstcry', '?', 'firstcry', 'asia', "'s", 'largest', 'online', 'store', 'baby', 'kids', 'products', '.', 'we', 'cater', 'needs', 'buyers', '(', 'mothers', 'buying', 'kids', ')', 'kid', 'born', 'upto', 'his/her', 'early', 'teens', '.', 'what', 'benefit', 'buying', 'firstcry', '?', 'our', 'company', 'philosophy', 'pretty', 'simple', ':', 'we', 'want', 'offer', 'best', 'possible', 'deal', 'customers', 'products', 'want', 'buy', 'children', '.', 'our', 'endeavour', 'ensure', 'get', 'widest', 'possible', 'choice', 'top', 'rated', 'brands', 'products', 'best', 'possible', 'price', 'anywhere', 'india', 'combined', 'best', 'possible', 'service', 'timely', 'delivery', 'products', 'doorstep', '.', 'where', 'offices', 'firstcry', 'located', '?', 'currently', 'office', 'located', 'pune', 'orders', 'shipped', 'warehouses', 'located', 'across', 'india', '.', 'what', 'products', 'firstcry', 'sell', '?', 'we', 'sell', 'products', 'leading', 'brands', 'babies', 'kids', 'across', 'sections', 'right', 'diapers', ',', 'baby', 'food', ',', 'infant', 'accessories', ',', 'gears', '(', 'strollers', ',', 'high', 'chairs', ')', ',', 'nursery', 'furniture', ',', 'clothes', '&', 'footwear', 'toys', 'school', 'products', '.', 'we', 'also', 'stock', 'items', 'leading', 'importers', 'domestic', 'manufacturers', 'country', '.', 'the', 'items', 'undergo', 'thorough', 'check', 'qa', 'team', 'stocked', '.', 'what', "'s", 'minimum', 'order', 'value', 'required', 'place', 'order', '?', 'to', 'place', 'order', ',', 'minimum', 'order', 'value', 'rs', '.', '249', 'required', '(', 'excluding', 'cod', 'charges', ',', 'shipping', 'charges', ',', 'taxes', 'value', 'reduced', 'application', 'coupons', 'offer', ')', '.', 'how', 'i', 'know', 'order', 'confirmed', '?', 'after', 'checking', 'payment', 'process', ',', 'get', 'confirmation', 'payment', 'processed', 'successfully', '.', 'you', 'also', 'get', 'mail', 'registered', 'email', 'id', ',', 'along', 'sms', 'registered', 'mobile', 'number', 'confirming', 'order', '.', 'how', 'i', 'check', 'order', 'status', '?', 'we', 'ship', 'package', 'within', '24', 'hours', 'receiving', 'order', '.', 'we', 'also', 'mail', 'name', 'courier', 'company', 'tracking', 'number', 'consignment', 'registered', 'email', 'address', '.', 'you', 'receive', 'sms', '.', 'in', 'case', 'receive', 'email', 'us', 'within', '24', 'hours', 'placing', 'order', 'please', 'check', 'spam', 'folder', '.', 'tracking', 'may', 'appear', 'online', 'another', '24', 'hours', 'cases', ',', 'please', 'wait', 'package', 'scanned', 'courier', 'company', '.', 'alternatively', ',', 'check', 'my', 'account', 'page', ',', 'track', 'shipment', 'option', 'gives', 'current', 'status', 'order', 'shipped', '.', 'is', 'safe', 'use', 'credit', 'card', 'online', 'firstcry.com', '?', 'we', 'accept', 'visa', ',', 'master', 'american', 'express', 'credit', 'cards', 'issued', 'india', 'accept', 'debit', 'cards', 'banks', 'issued', 'india', '.', 'international', 'credit/debit', 'card', 'transactions', 'also', 'accepted', 'paypal', ',', 'place', 'orders', 'firstcry', 'outside', 'india', 'ship', 'dear', 'ones', 'india', '.', 'all', 'transactions', 'online', 'protected', '&', 'secured', 'ssl', '(', 'secure', 'socket', 'layer', ')', 'technology', 'godaddy.com', '.', 'it', 'encrypts', 'credit', 'card', 'relevant', 'information', 'entire', 'transaction', 'process', '.', 'this', 'encryption', 'makes', 'shopping', 'experience', 'safe', 'secure', '.', 'what', 'item', 'stock', '?', 'we', 'make', 'every', 'effort', 'keep', 'products', 'stock', '.', 'however', ',', 'may', 'times', 'unexpected', 'demands', 'exceed', 'supply', '.', 'we', 'notify', 'time', 'check', 'item', 'selected', 'stock', '.', 'in', 'rare', 'circumstance', 'order', 'accepted', 'due', 'reasons', 'able', 'ship', ',', 'notify', 'within', '24', 'hours', 'money', 'returned', 'mode', 'payment', 'made', 'within', '10', 'working', 'days', '.', 'some', 'items', '(', 'restocked', 'regularly', ')', 'temporarily', 'stock', 'may', ...

# %% [markdown]
# remove all tokens that are not alphabetic

# %%
# remove all tokens that are not alphabetic
words = [word for word in filtered_sentence_lower if word.isalpha()]
print(len(words))
# Out:
# 910

# %% [markdown]
# Find out most frequent words

# %%
from collections import Counter
Counter = Counter(words)
most_occur = Counter.most_common(10) 
  
print(most_occur)
# Out:
# [('bank', 31), ('order', 18), ('we', 17), ('products', 16), ('india', 15), ('gst', 15), ('what', 10), ('delivery', 9), ('also', 9), ('orders', 8)]

# %% [markdown]
# Part of speech tagging

# %%
words_pos=[w for w in nltk.pos_tag(filtered_sentence_lower)]
print(words_pos)
# Out:
# [('what', 'WP'), ('firstcry', 'NN'), ('?', '.'), ('firstcry', 'NN'), ('asia', 'NN'), ("'s", 'POS'), ('largest', 'JJS'), ('online', 'NN'), ('store', 'NN'), ('baby', 'NN'), ('kids', 'NNS'), ('products', 'NNS'), ('.', '.'), ('we', 'PRP'), ('cater', 'VBP'), ('needs', 'JJ'), ('buyers', 'NNS'), ('(', '('), ('mothers', 'NNS'), ('buying', 'VBG'), ('kids', 'NNS'), (')', ')'), ('kid', 'VBP'), ('born', 'VBN'), ('upto', 'JJ'), ('his/her', 'RB'), ('early', 'JJ'), ('teens', 'NNS'), ('.', '.'), ('what', 'WP'), ('benefit', 'VBD'), ('buying', 'VBG'), ('firstcry', 'NN'), ('?', '.'), ('our', 'PRP$'), ('company', 'NN'), ('philosophy', 'NN'), ('pretty', 'RB'), ('simple', 'JJ'), (':', ':'), ('we', 'PRP'), ('want', 'VBP'), ('offer', 'NN'), ('best', 'RBS'), ('possible', 'JJ'), ('deal', 'NN'), ('customers', 'NNS'), ('products', 'NNS'), ('want', 'VBP'), ('buy', 'NN'), ('children', 'NNS'), ('.', '.'), ('our', 'PRP$'), ('endeavour', 'JJ'), ('ensure', 'VB'), ('get', 'VB'), ('widest', 'JJS'), ('possible', 'JJ'), ('choice', 'NN'), ('top', 'NN'), ('rated', 'VBN'), ('brands', 'NNS'), ('products', 'NNS'), ('best', 'RB'), ('possible', 'JJ'), ('price', 'NN'), ('anywhere', 'RB'), ('india', 'JJ'), ('combined', 'VBN'), ('best', 'JJS'), ('possible', 'JJ'), ('service', 'NN'), ('timely', 'RB'), ('delivery', 'NN'), ('products', 'NNS'), ('doorstep', 'NN'), ('.', '.'), ('where', 'WRB'), ('offices', 'NNS'), ('firstcry', 'VBP'), ('located', 'VBN'), ('?', '.'), ('currently', 'RB'), ('office', 'NN'), ('located', 'VBN'), ('pune', 'IN'), ('orders', 'NNS'), ('shipped', 'VBN'), ('warehouses', 'NNS'), ('located', 'VBN'), ('across', 'IN'), ('india', 'NN'), ('.', '.'), ('what', 'WP'), ('products', 'NNS'), ('firstcry', 'VBP'), ('sell', 'VB'), ('?', '.'), ('we', 'PRP'), ('sell', 'VBP'), ('products', 'NNS'), ('leading', 'VBG'), ('brands', 'NNS'), ('babies', 'NNS'), ('kids', 'NNS'), ('across', 'IN'), ('sections', 'NNS'), ('right', 'JJ'), ('diapers', 'NNS'), (',', ','), ('baby', 'NN'), ('food', 'NN'), (',', ','), ('infant', 'NN'), ('accessories', 'NNS'), (',', ','), ('gears', 'NNS'), ('(', '('), ('strollers', 'NNS'), (',', ','), ('high', 'JJ'), ('chairs', 'NNS'), (')', ')'), (',', ','), ('nursery', 'JJ'), ('furniture', 'NN'), (',', ','), ('clothes', 'NNS'), ('&', 'CC'), ('footwear', 'JJ'), ('toys', 'JJ'), ('school', 'NN'), ('products', 'NNS'), ('.', '.'), ('we', 'PRP'), ('also', 'RB'), ('stock', 'NN'), ('items', 'NNS'), ('leading', 'VBG'), ('importers', 'NNS'), ('domestic', 'JJ'), ('manufacturers', 'NNS'), ('country', 'NN'), ('.', '.'), ('the', 'DT'), ('items', 'NNS'), ('undergo', 'VBP'), ('thorough', 'JJ'), ('check', 'NN'), ('qa', 'NN'), ('team', 'NN'), ('stocked', 'VBD'), ('.', '.'), ('what', 'WP'), ("'s", 'VBZ'), ('minimum', 'JJ'), ('order', 'NN'), ('value', 'NN'), ('required', 'VBN'), ('place', 'NN'), ('order', 'NN'), ('?', '.'), ('to', 'TO'), ('place', 'VB'), ('order', 'NN'), (',', ','), ('minimum', 'NN'), ('order', 'NN'), ('value', 'NN'), ('rs', 'NN'), ('.', '.'), ('249', 'CD'), ('required', 'VBN'), ('(', '('), ('excluding', 'VBG'), ('cod', 'NN'), ('charges', 'NNS'), (',', ','), ('shipping', 'NN'), ('charges', 'NNS'), (',', ','), ('taxes', 'NNS'), ('value', 'NN'), ('reduced', 'VBN'), ('application', 'NN'), ('coupons', 'NNS'), ('offer', 'VBP'), (')', ')'), ('.', '.'), ('how', 'WRB'), ('i', 'JJ'), ('know', 'VBP'), ('order', 'NN'), ('confirmed', 'VBN'), ('?', '.'), ('after', 'IN'), ('checking', 'VBG'), ('payment', 'NN'), ('process', 'NN'), (',', ','), ('get', 'VB'), ('confirmation', 'JJ'), ('payment', 'NN'), ('processed', 'VBN'), ('successfully', 'RB'), ('.', '.'), ('you', 'PRP'), ('also', 'RB'), ('get', 'VBP'), ('mail', 'NN'), ('registered', 'VBN'), ('email', 'JJ'), ('id', 'NN'), (',', ','), ('along', 'IN'), ('sms', 'NNS'), ('registered', 'VBN'), ('mobile', 'JJ'), ('number', 'NN'), ('confirming', 'VBG'), ('order', 'NN'), ('.', '.'), ('how', 'WRB'), ('i', 'JJ'), ('check', 'VBP'), ('order', 'NN'), ('status', 'NN'), ('?', '.'), ('we', 'PRP'), ('ship', 'VBP'), ('package', 'VB'), ('withi ...

# %% [markdown]
# Filter out verbs

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp = nltk.RegexpParser(grammar)
#for a in words_pos:
#    print(a[1])
result = cp.parse(words_pos)
print(result)
result.draw()
# Out:
# (S
#   what/WP
#   (NP firstcry/NN)
#   ?/.
#   (NP firstcry/NN)
#   (NP asia/NN)
#   's/POS
#   largest/JJS
#   (NP online/NN)
#   (NP store/NN)
#   (NP baby/NN)
#   kids/NNS
#   products/NNS
#   ./.
#   we/PRP
#   cater/VBP
#   needs/JJ
#   buyers/NNS
#   (/(
#   mothers/NNS
#   buying/VBG
#   kids/NNS
#   )/)
#   kid/VBP
#   born/VBN
#   upto/JJ
#   his/her/RB
#   early/JJ
#   teens/NNS
#   ./.
#   what/WP
#   benefit/VBD
#   buying/VBG
#   (NP firstcry/NN)
#   ?/.
#   our/PRP$
#   (NP company/NN)
#   (NP philosophy/NN)
#   pretty/RB
#   simple/JJ
#   :/:
#   we/PRP
#   want/VBP
#   (NP offer/NN)
#   best/RBS
#   (NP possible/JJ deal/NN)
#   customers/NNS
#   products/NNS
#   want/VBP
#   (NP buy/NN)
#   children/NNS
#   ./.
#   our/PRP$
#   endeavour/JJ
#   ensure/VB
#   get/VB
#   widest/JJS
#   (NP possible/JJ choice/NN)
#   (NP top/NN)
#   rated/VBN
#   brands/NNS
#   products/NNS
#   best/RB
#   (NP possible/JJ price/NN)
#   anywhere/RB
#   india/JJ
#   combined/VBN
#   best/JJS
#   (NP possible/JJ service/NN)
#   timely/RB
#   (NP delivery/NN)
#   products/NNS
#   (NP doorstep/NN)
#   ./.
#   where/WRB
#   offices/NNS
#   firstcry/VBP
#   located/VBN
#   ?/.
#   currently/RB
#   (NP office/NN)
#   located/VBN
#   pune/IN
#   orders/NNS
#   shipped/VBN
#   warehouses/NNS
#   located/VBN
#   across/IN
#   (NP india/NN)
#   ./.
#   what/WP
#   products/NNS
#   firstcry/VBP
#   sell/VB
#   ?/.
#   we/PRP
#   sell/VBP
#   products/NNS
#   leading/VBG
#   brands/NNS
#   babies/NNS
#   kids/NNS
#   across/IN
#   sections/NNS
#   right/JJ
#   diapers/NNS
#   ,/,
#   (NP baby/NN)
#   (NP food/NN)
#   ,/,
#   (NP infant/NN)
#   accessories/NNS
#   ,/,
#   gears/NNS
#   (/(
#   strollers/NNS
#   ,/,
#   high/JJ
#   chairs/NNS
#   )/)
#   ,/,
#   (NP nursery/JJ furniture/NN)
#   ,/,
#   clothes/NNS
#   &/CC
#   (NP footwear/JJ toys/JJ school/NN)
#   products/NNS
#   ./.
#   we/PRP
#   also/RB
#   (NP stock/NN)
#   items/NNS
#   leading/VBG
#   importers/NNS
#   domestic/JJ
#   manufacturers/NNS
#   (NP country/NN)
#   ./.
#   the/DT
#   items/NNS
#   undergo/VBP
#   (NP thorough/JJ check/NN)
#   (NP qa/NN)
#   (NP team/NN)
#   stocked/VBD
#   ./.
#   what/WP
#   's/VBZ
#   (NP minimum/JJ order/NN)
#   (NP value/NN)
#   required/VBN
#   (NP place/NN)
#   (NP order/NN)
#   ?/.
#   to/TO
#   place/VB
#   (NP order/NN)
#   ,/,
#   (NP minimum/NN)
#   (NP order/NN)
#   (NP value/NN)
#   (NP rs/NN)
#   ./.
#   249/CD
#   required/VBN
#   (/(
#   excluding/VBG
#   (NP cod/NN)
#   charges/NNS
#   ,/,
#   (NP shipping/NN)
#   charges/NNS
#   ,/,
#   taxes/NNS
#   (NP value/NN)
#   reduced/VBN
#   (NP application/NN)
#   coupons/NNS
#   offer/VBP
#   )/)
#   ./.
#   how/WRB
#   i/JJ
#   know/VBP
#   (NP order/NN)
#   confirmed/VBN
#   ?/.
#   after/IN
#   checking/VBG
#   (NP payment/NN)
#   (NP process/NN)
#   ,/,
#   get/VB
#   (NP confirmation/JJ payment/NN)
#   processed/VBN
#   successfully/RB
#   ./.
#   you/PRP
#   also/RB
#   get/VBP
#   (NP mail/NN)
#   registered/VBN
#   (NP email/JJ id/NN)
#   ,/,
#   along/IN
#   sms/NNS
#   registered/VBN
#   (NP mobile/JJ number/NN)
#   confirming/VBG
#   (NP order/NN)
#   ./.
#   how/WRB
#   i/JJ
#   check/VBP
#   (NP order/NN)
#   (NP status/NN)
#   ?/.
#   we/PRP
#   ship/VBP
#   package/VB
#   within/IN
#   24/CD
#   hours/NNS
#   receiving/VBG
#   (NP order/NN)
#   ./.
#   we/PRP
#   also/RB
#   mail/VBP
#   (NP name/NN)
#   (NP courier/NN)
#   (NP company/NN)
#   tracking/VBG
#   (NP number/NN)
#   (NP consignment/NN)
#   registered/VBD
#   (NP email/JJ address/NN)
#   ./.
#   you/PRP
#   receive/VBP
#   sms/NNS
#   ./.
#   in/IN
#   (NP case/NN)
#   receive/VBP
#   (NP email/NN)
#   us/PRP
#   within/IN
#   24/CD
#   hours/NNS
#   placing/VBG
#   (NP order/NN)
#   (NP please/NN)
#   check/VB
#   (NP spam/JJ folder/NN)
#   ./.
#   (NP tracking/NN)
#   may/MD
#   appear/VB
#   online/VB
#   another/DT
#   24/CD
#   hours/NNS
#   cases/NNS
#   ,/,
#   (NP please/NN)
#   (NP wait/JJ package/NN)
#   scanned/VBD
#   courier/JJR
#   (NP company/NN)
#   ./.
#   alternatively/RB
#   ,/,
#   check/VB
#   my/PRP$
#   (NP account/NN)
#   (NP page/NN)
#   ,/,
#   (NP track/NN)
#   (NP shipment/NN)
#   (NP option/NN)
#   gives/VBZ
#   (NP current/JJ status/NN)
#   (NP order/NN)
#   shipped/VBN
#   ./.
#   is/VBZ
#   (NP safe/JJ use/NN)
#   (NP credit/NN)
#   (NP card/NN)
#   (NP online/NN)
#   (NP firstcry.com/NN)
#   ?/.
#   we/PRP
#   accept/VBP
#   visa/RB
#   ,/,
#   (NP master/NN)
#   (NP american/JJ express/NN)
#   (NP credit/NN)
#   cards/NNS
#   issued/VBN
#   (NP india/JJ accept/JJ debit/NN)
#   cards/NNS
#   banks/NNS
#   issued/VBD
#   india/JJ
#   ./.
#   (NP international/JJ credit/debit/NN)
#   (NP card/NN)
#   transactions/NNS
#   also/RB
#   accepted/VBD
#   paypal/JJ
#   ,/,
#   (NP place/NN)
#   orders/NNS
#   firstcry/VBP
#   outside/IN
#   (NP india/JJ ship/NN)
#   dear/JJ
#   ones/NNS
#   india/RB
#   ./.
#   all/DT
#   transactions/NNS
#   online/VBP
#   protected/VBN
#   &/CC
#   secured/VBN
#   (NP ssl/NN)
#   (/(
#   (NP secure/JJ socket/NN)
#   (NP layer/NN)
#   )/)
#   (NP technology/NN)
#   (NP godaddy.com/NN)
#   ./.
#   it/PRP
#   encrypts/VBZ
#   (NP credit/NN)
#   (NP card/NN)
#   (NP relevant/JJ information/NN)
#   (NP entire/JJ transaction/NN)
#   (NP process/NN)
#   ./.
#   (NP this/DT encryption/NN)
#   makes/VBZ
#   shopping/VBG
#   experience/VB
#   (NP safe/JJ secure/NN)
#   ./.
#   what/WP
#   (NP item/NN)
#   (NP stock/NN)
#   ?/.
#   we/PRP
#   make/VBP
#   (NP every/DT effort/NN)
#   (NP keep/NN)
#   products/NNS
#   (NP stock/NN)
#   ./.
#   however/RB
#   ,/,
#   may/MD
#   times/VB
#   unexpected/JJ
#   demands/NNS
#   exceed/VBP
#   (NP supply/NN)
#   ./.
#   we/PRP
#   notify/VBP
#   (NP time/NN)
#   (NP check/NN)
#   (NP item/NN)
#   selected/VBD
#   (NP stock/NN)
#   ./.
#   in/IN
#   (NP rare/JJ circumstance/NN)
#   (NP order/NN)
#   accepted/VBD
#   due/JJ
#   reasons/NNS
#   (NP able/JJ ship/NN)
#   ,/,
#   notify/VB
#   within/IN
#   24/CD
#   hours/NNS
#   (NP money/NN)
#   returned/VBN
#   mode/CD
#   (NP payment/NN)
#   made/VBD
#   within/IN
#   10/CD
#   working/JJ
#   days/NNS
#   ./.
#   some/DT
#   items/NNS
#   (/(
#   restocked/VBN
#   regularly/RB
#   )/)
#   temporarily/RB
#   (NP stock/NN)
#   may/MD
#   appear/VB
#   (NP display/NN)
#   (NP stock/NN)
#   (NP tag/NN)
#   ./.
#   you/PRP
#   use/VBP
#   notify/VB
#   me/PRP
#   (NP option/NN)
#   inform/VB
#   (NP product/NN)
#   replenished/VBN
#   (NP available/JJ sale/NN)
#   ./.
#   are/VBP
#   hidden/JJ
#   charges/NNS
#   like/IN
#   (NP octroi/JJ entry/NN)
#   (NP tax/NN)
#   ?/.
#   you/PRP
#   get/VBP
#   (NP final/JJ price/NN)
#   (NP check/NN)
#   ./.
#   our/PRP$
#   prices/NNS
#   inclusive/VBP
#   (NP need/JJ pay/NN)
#   (NP anything/NN)
#   extra/JJ
#   ./.
#   how/WRB
#   products/NNS
#   packaged/VBN
#   ?/.
#   (NP each/DT individual/NN)
#   products/NNS
#   securely/RB
#   packaged/VBD
#   (NP bubble/JJ wrap/NN)
#   put/VBD
#   (NP box/NN)
#   ./.
#   (NP the/DT box/NN)
#   sealed/VBD
#   well/RB
#   ensuring/VBG
#   (NP safe/JJ delivery/NN)
#   (NP doorstep/NN)
#   ./.
#   do/VB
#   'll/MD
#   deliver/VB
#   products/NNS
#   outside/IN
#   (NP india/NN)
#   ?/.
#   we/PRP
#   ship/VBP
#   products/NNS
#   outside/IN
#   (NP india/JJ site/NN)
#   accessible/JJ
#   take/JJ
#   orders/NNS
#   around/IN
#   (NP world/NN)
#   provided/VBD
#   (NP shipping/NN)
#   (NP address/NN)
#   (NP india/NN)
#   ./.
#   is/VBZ
#   (NP mandatory/JJ register/NN)
#   placing/VBG
#   (NP order/NN)
#   ?/.
#   you/PRP
#   place/VBP
#   (NP order/NN)
#   providing/VBG
#   us/PRP
#   (NP email/JJ address/NN)
#   ./.
#   however/RB
#   ,/,
#   recommended/VBD
#   (NP register/NN)
#   us/PRP
#   (NP order/NN)
#   receive/VBP
#   timely/JJ
#   offers/NNS
#   also/RB
#   maintain/VBP
#   (NP wishlist/JJ account/NN)
#   &/CC
#   (NP address/NN)
#   details/NNS
#   ./.
#   how/WRB
#   long/JJ
#   take/VB
#   receive/JJ
#   orders/NNS
#   ?/.
#   for/IN
#   areas/NNS
#   serviced/VBN
#   reputed/JJ
#   couriers/NNS
#   ,/,
#   (NP delivery/NN)
#   (NP time/NN)
#   would/MD
#   within/IN
#   3/CD
#   4/CD
#   (NP business/NN)
#   days/NNS
#   (NP dispatch/NN)
#   (/(
#   (NP business/NN)
#   days/NNS
#   exclude/VBP
#   sundays/JJ
#   holidays/NNS
#   )/)
#   ./.
#   however/RB
#   items/NNS
#   weighing/VBG
#   2/CD
#   (NP kilos/NN)
#   may/MD
#   take/VB
#   (NP couple/NN)
#   days/NNS
#   longer/RBR
#   reach/VBP
#   ./.
#   for/IN
#   areas/NNS
#   products/NNS
#   shipped/VBD
#   (NP indian/JJ postal/JJ service/NN)
#   may/MD
#   take/VB
#   1-2/JJ
#   weeks/NNS
#   depending/VBG
#   (NP location/NN)
#   ./.
#   can/MD
#   i/VB
#   ship/JJ
#   different/JJ
#   items/NNS
#   (NP order/NN)
#   (NP different/JJ shipping/NN)
#   addresses/NNS
#   ?/.
#   we/PRP
#   process/VBP
#   one/CD
#   (NP shipping/NN)
#   (NP address/NN)
#   per/IN
#   (NP order/NN)
#   ./.
#   so/RB
#   ,/,
#   would/MD
#   like/VB
#   (NP order/NN)
#   several/JJ
#   items/NNS
#   ship/JJ
#   different/JJ
#   people/NNS
#   ,/,
#   please/VB
#   (NP treat/NN)
#   separate/JJ
#   orders/NNS
#   ./.
#   who/WP
#   pays/VBZ
#   (NP shipping/NN)
#   charges/NNS
#   ?/.
#   we/PRP
#   provide/VBP
#   (NP free/JJ shipping/NN)
#   orders/NNS
#   (NP equal/JJ rs/NN)
#   ./.
#   499/-/JJ
#   (/(
#   excluding/VBG
#   (NP cod/NN)
#   charges/NNS
#   ,/,
#   (NP shipping/NN)
#   charges/NNS
#   ,/,
#   taxes/NNS
#   (NP value/NN)
#   reduced/VBN
#   (NP application/NN)
#   coupons/NNS
#   offer/VBP
#   )/)
#   ./.
#   for/IN
#   orders/NNS
#   rs/VBP
#   ./.
#   499/CD
#   (/(
#   exclusions/NNS
#   )/)
#   ,/,
#   shipping/VBG
#   charges/NNS
#   rs/VBP
#   ./.
#   50/CD
#   (NP apply/NN)
#   ./.
#   what/WP
#   (NP gst/NN)
#   ?/.
#   (NP gst/NN)
#   means/VBZ
#   goods/NNS
#   (NP service/NN)
#   (NP tax/NN)
#   ./.
#   it/PRP
#   (NP single/JJ indirect/JJ tax/NN)
#   (NP sale/NN)
#   goods/NNS
#   services/NNS
#   throughout/IN
#   (NP india/NN)
#   ./.
#   (NP gst/NN)
#   (NP applicable/JJ w.e.f/NN)
#   ./.
#   1st/CD
#   (NP july/NN)
#   ,/,
#   2017/CD
#   ./.
#   how/WRB
#   (NP gst/JJ amount/NN)
#   calculated/VBD
#   discounted/VBN
#   (NP price/NN)
#   ?/.
#   (NP gst/NN)
#   calculated/VBD
#   (NP basis/NN)
#   rates/NNS
#   mentioned/VBD
#   gst/JJ
#   laws/NNS
#   (NP category/JJ product/NN)
#   ,/,
#   (NP customer/NN)
#   (NP location/NN)
#   (NP applicable/JJ discount/NN)
#   (NP product/NN)
#   (NP time/NN)
#   purchase.gst/RB
#   discounted/VBN
#   (NP price/NN)
#   applicable/JJ
#   products/NNS
#   discount/VBP
#   19/CD
#   (NP %/NN)
#   ./.
#   (NP please/NN)
#   (NP refer/NN)
#   terms/NNS
#   use/VBP
#   full/JJ
#   details/NNS
#   ./.
#   (NP the/DT gst/NN)
#   collected/VBD
#   (NP discounted/JJ price/NN)
#   duly/RB
#   deposited/VBD
#   (NP respective/JJ gst/NN)
#   authorities/NNS
#   (NP jurisdiction/NN)
#   adjusted/VBN
#   per/IN
#   (NP applicable/JJ gst/NN)
#   (NP act/NN)
#   rules/NNS
#   do/VBP
#   (NP i/JJ pay/NN)
#   (NP gst/NN)
#   (NP purchase/NN)
#   (NP gift/NN)
#   (NP certificate/NN)
#   &/CC
#   guaranteed/VBN
#   savings/NNS
#   (NP offer/NN)
#   ?/.
#   no/DT
#   ./.
#   (NP gst/NN)
#   charged/VBD
#   customers/NNS
#   buying/VBG
#   (NP gift/NN)
#   certificates/NNS
#   guaranteed/VBP
#   savings/NNS
#   (NP offer/NN)
#   ./.
#   will/MD
#   gst/VB
#   (NP amount/NN)
#   refunded/VBN
#   (NP order/NN)
#   (NP cancellation/NN)
#   returns/NNS
#   ?/.
#   yes/UH
#   ./.
#   (NP gst/NN)
#   (NP amount/NN)
#   collected/VBD
#   returned/VBN
#   (NP customer/NN)
#   's/POS
#   (NP source/NN)
#   (NP method/NN)
#   (NP time/NN)
#   (NP cancellation/NN)
#   returns/NNS
#   ./.
#   what/WP
#   (NP gst/NN)
#   (NP amount/NN)
#   purchased/VBD
#   products/NNS
#   comes/VBZ
#   (NP limit/NN)
#   defined/VBD
#   (NP govt/NN)
#   ./.
#   ?/.
#   we/PRP
#   (NP ready/JJ share/NN)
#   details/NNS
#   gst/VBP
#   (NP kind/NN)
#   (NP perusal/NN)
#   would/MD
#   happily/RB
#   return/VB
#   (NP money/NN)
#   back/RB
#   (NP case/NN)
#   found/VBD
#   (NP excessive/JJ amount/NN)
#   charged/VBN
#   (NP due/JJ miscalculation/NN)
#   ./.
#   what/WP
#   happens/VBZ
#   (NP i/NN)
#   (NP available/JJ time/NN)
#   (NP delivery/NN)
#   ?/.
#   our/PRP$
#   (NP delivery/NN)
#   partners/NNS
#   attempt/VBP
#   (NP deliver/JJ package/NN)
#   (NP thrice/NN)
#   returned/VBD
#   back/RB
#   (NP warehouse/NN)
#   ./.
#   please/VB
#   provide/RB
#   (NP mobile/JJ number/NN)
#   (NP delivery/NN)
#   (NP address/NN)
#   (NP help/NN)
#   making/VBG
#   (NP faster/JJ delivery/NN)
#   ./.
#   what/WP
#   (NP return/NN)
#   (NP policy/NN)
#   ?/.
#   we/PRP
#   30/CD
#   days/NNS
#   (NP return/NN)
#   (NP policy/NN)
#   clothes/NNS
#   &/CC
#   footwear/JJ
#   7/CD
#   days/NNS
#   (NP return/NN)
#   (NP policy/NN)
#   items/NNS
#   except/IN
#   personal/JJ
#   products/NNS
#   diapers/NNS
#   ,/,
#   wipes/NNS
#   creams/VBP
#   ./.
#   what/WP
#   options/NNS
#   i/VBP
#   making/VBG
#   (NP payment/NN)
#   ?/.
#   we/PRP
#   accept/VBP
#   payments/NNS
#   debit/VB
#   (NP credit/NN)
#   (NP card/NN)
#   also/RB
#   (NP net/JJ banking.credit/NN)
#   cards/NNS
#   &/CC
#   (NP debit/NN)
#   cards/NNS
#   -/:
#   we/PRP
#   accept/VBP
#   visa/RB
#   ,/,
#   (NP master/NN)
#   (NP american/JJ express/NN)
#   (NP credit/NN)
#   cards/NNS
#   issued/VBN
#   (NP india/JJ accept/JJ debit/NN)
#   cards/NNS
#   banks/NNS
#   issued/VBD
#   india/JJ
#   ./.
#   (NP international/JJ credit/debit/NN)
#   (NP card/NN)
#   transactions/NNS
#   also/RB
#   accepted/VBD
#   (NP pay/JJ pal.net/NN)
#   banking/VBG
#   -/:
#   we/PRP
#   accept/VBP
#   (NP axis/JJ bank/NN)
#   ,/,
#   (NP bank/NN)
#   (NP baroda/NN)
#   (/(
#   retail/JJ
#   &/CC
#   (NP corporate/JJ banking/NN)
#   )/)
#   ,/,
#   (NP bank/NN)
#   of/IN
#   india/NNP
#   ,/,
#   (NP bank/NN)
#   (NP maharashtra/NN)
#   ,/,
#   (NP canara/NN)
#   (NP bank/NN)
#   ,/,
#   (NP corporation/NN)
#   (NP bank/NN)
#   ,/,
#   (NP citibank/NN)
#   ,/,
#   (NP deutsche/NN)
#   (NP bank/NN)
#   ,/,
#   (NP federal/JJ bank/NN)
#   fed/VBN
#   (NP net/JJ banking/NN)
#   ,/,
#   (NP hdfc/JJ bank/NN)
#   ,/,
#   (NP icici/JJ bank/NN)
#   ,/,
#   (NP idbi/JJ net/NN)
#   (NP banking/NN)
#   ,/,
#   (NP indusind/NN)
#   (NP bank/NN)
#   ,/,
#   ing/VBG
#   (NP vysya/JJ bank/NN)
#   (NP ltd./NN)
#   ,/,
#   (NP jammu/NN)
#   &/CC
#   kashmir/NNP
#   (NP bank/NN)
#   ,/,
#   karnataka/NNP
#   (NP bank/NN)
#   ,/,
#   karur/VB
#   vysya/FW
#   (NP bank/NN)
#   limited/VBD
#   ,/,
#   kotak/FW
#   mahindra/FW
#   (NP bank/NN)
#   ,/,
#   lakshmi/JJ
#   vilas/NNS
#   (NP bank/NN)
#   ,/,
#   (NP oriental/JJ bank/NN)
#   of/IN
#   (NP commerce/NN)
#   ,/,
#   punjab/VBP
#   (NP national/JJ bank/NN)
#   ,/,
#   (NP the/DT bank/NN)
#   of/IN
#   (NP rajasthan/NN)
#   ,/,
#   (NP royal/JJ bank/NN)
#   (NP scotland/NN)
#   ,/,
#   (NP south/JJ indian/JJ bank/NN)
#   ,/,
#   (NP state/NN)
#   (NP bank/NN)
#   of/IN
#   (NP india/NN)
#   ,/,
#   (NP state/NN)
#   (NP bank/NN)
#   (NP indore/NN)
#   ,/,
#   (NP state/NN)
#   (NP bank/NN)
#   (NP hyderabad/NN)
#   ,/,
#   (NP state/NN)
#   (NP bank/NN)
#   (NP travancore/NN)
#   ,/,
#   (NP syndicate/NN)
#   (NP bank/NN)
#   ,/,
#   tamilnad/EX
#   mercantile/IN
#   (NP bank/NN)
#   (NP ltd./NN)
#   ,/,
#   (NP union/NN)
#   (NP bank/NN)
#   of/IN
#   (NP india/NN)
#   ,/,
#   (NP vijaya/JJ bank/NN)
#   ,/,
#   yes/UH
#   (NP bank/NN)
#   you/PRP
#   also/RB
#   pay/VBP
#   (NP cash/NN)
#   on/IN
#   (NP delivery/NN)
#   (/(
#   (NP c-o-d/NN)
#   )/)
#   -/:
#   you/PRP
#   also/RB
#   pay/VBP
#   (NP cash/NN)
#   on/IN
#   (NP delivery/NN)
#   (/(
#   (NP cod/NN)
#   )/)
#   ./.
#   in/IN
#   (NP case/NN)
#   (NP pay/NN)
#   (NP cash/NN)
#   courier/JJR
#   (NP person/NN)
#   accepting/VBG
#   goods/NNS
#   ./.
#   (NP cod/NN)
#   payments/NNS
#   would/MD
#   accepted/VBD
#   orders/NNS
#   (NP total/JJ invoice/NN)
#   (NP value/NN)
#   greater/JJR
#   (NP equal/JJ rs/NN)
#   ./.
#   (NP 499/-/JJ rs/NN)
#   ./.
#   15,000/-/JJ
#   ./.)
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-21-72a6b1190c3d> in <module>()
#       5 result = cp.parse(words_pos)
#       6 print(result)
# ----> 7 result.draw()
#
# /usr/local/lib/python3.6/dist-packages/nltk/tree.py in draw(self)
#     688         """
#     689         from nltk.draw.tree import draw_trees
# --> 690         draw_trees(self)
#     691
#     692     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#     861     :rtype: None
#     862     """
# --> 863     TreeView(*trees).mainloop()
#     864     return
#     865
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
#     754         self._trees = trees
#     755
# --> 756         self._top = Tk()
#     757         self._top.title('NLTK')
#     758         self._top.bind('<Control-x>', self.destroy)
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# Named entity recognition

# %%
words_ne = nltk.ne_chunk(words_pos)
words_ne.draw()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-22-f528a1c02117> in <module>()
#       1 words_ne = nltk.ne_chunk(words_pos)
# ----> 2 words_ne.draw()
#
# /usr/local/lib/python3.6/dist-packages/nltk/tree.py in draw(self)
#     688         """
#     689         from nltk.draw.tree import draw_trees
# --> 690         draw_trees(self)
#     691
#     692     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#     861     :rtype: None
#     862     """
# --> 863     TreeView(*trees).mainloop()
#     864     return
#     865
#
# /usr/local/lib/python3.6/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
#     754         self._trees = trees
#     755
# --> 756         self._top = Tk()
#     757         self._top.title('NLTK')
#     758         self._top.bind('<Control-x>', self.destroy)
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# Wordnet corpus

# %%
from nltk.corpus import wordnet
syns = wordnet.synsets("program")
print(syns[0].name())
print(syns[0].lemmas()[0].name())
print(syns[0].definition())
print(syns[0].examples())
# Out:
# plan.n.01
# plan
# a series of steps to be carried out or goals to be accomplished
# ['they drew up a six-step plan', 'they discussed plans for a new bond issue']

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(set(synonyms))
print(set(antonyms))
# Out:
# {'full', 'soundly', 'beneficial', 'dependable', 'proficient', 'well', 'good', 'just', 'adept', 'dear', 'ripe', 'near', 'respectable', 'honest', 'secure', 'right', 'practiced', 'safe', 'estimable', 'skillful', 'serious', 'sound', 'effective', 'trade_good', 'thoroughly', 'honorable', 'unspoiled', 'expert', 'salutary', 'in_effect', 'undecomposed', 'unspoilt', 'goodness', 'in_force', 'commodity', 'upright', 'skilful'}
# {'badness', 'bad', 'evilness', 'ill', 'evil'}

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')
print(w1.wup_similarity(w2))

w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('car.n.01')
print(w1.wup_similarity(w2))

w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('cat.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091
# 0.6956521739130435
# 0.32
